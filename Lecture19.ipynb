# %% [markdown]
# # *Lecture 19*
#
# # Discretization Methods
#
# In previous lectures, the ordinary differential equation boundary value problems were solved numerically by converting the problem to an initial value problem.
# Especially with the **shooting method**, the trick was to find the right *initial* value that satisfied the boundary conditions at the endpoints of the interval.
# In all cases, we kept the differential equations themselves and used an ODE solver to evolve the system from the one end of the interval to the other (to a specific time $t$ or a specific point $x$).
#
# For one-dimensional cases, the shooting method is almost always good enough to find a good solution.
# The reason is that it is fairly straightforward to adjust the starting values to match a boundary condition at a single endpoint.
# For higher-dimensional cases, the "endpoint" is not a single point, but rather a $N$-dimensional coordinate.  For example, a boundary condition in 2-D might need to be satisfied at the boundary of a circular area.  In that case, the boundary condition must be satisfied everywhere on the circle simultaneously.
#
# Before we move on to discretization methods, let's follow up on the orbital mechanics introduction from last lecture.

# %% [markdown]
# # Orbital Mechanics Recap
#
#
#
# All we need for orbital mechanics in the solar system is
# the force between
# a body of mass $m$ and another body of mass $M$:
#
# $$F^{(g)} = - \frac{G m M} { r^2}$$
#
# where $r$ is the distance between objects, $G$ is the universal gravitational
# constant, and the attractive force lies along the line between the two.
#
# The equation of motion is still
#
# $$\mathbf{F} = m \mathbf{a} = m \frac{d^2 \mathbf{x}}{dt^2}$$
#
# with the force components given by
#
# $$\begin{align}
# F_x & = F^{(g)} \cos \theta = F^{(g)}\frac{x} { r} = F^{(g)}\frac{x} {
# \sqrt{x^2+y^2}},\\ F_y & = F^{(g)} \sin \theta = F^{(g)}\frac{y} { r} =
# F^{(g)}\frac{y} { \sqrt{x^2+y^2}}
# \end{align}$$
#
# The equation of motion can be rewritten as usual as two simultaneous second-order
# ODE’s:
#
# $$\frac{d^2 x}{dt^2} = -GM \frac{x}{r^3}, \quad \frac{d^2 y}{dt^2} = -GM \frac{y}{r^3}$$
#
# The solution to these equations can be calculated with the following steps:
#
# 1. Calculate the units, for example, $GM = 1$, and define initial conditions
#
# 2.  Modify your ODE solver program to solve the first-order differential equations.
#
# 3.  Establish that you use small enough time steps so that the orbits
#     are closed and fall upon themselves.

# %% [markdown]
# ## Example: Moon Lander
#
# We would like to send a lunar lander to the Moon.
# We need to consider the gravitational forces on the lander from both Moon and Earth.
#
# To simplify the problem a bit, we'll assume that the lunar lander does not affect the orbits of the Moon and Earth.
# We'll also assume that their orbits are circular, and that they orbit a common-center-of-mass point.
#
# If the distance between Earth and Moon is $d$, then the radii of the respective orbits are
#
# $$\begin{align}
# r_E &= \frac{m_M}{m_M + m_E} d \\
# r_M &= \frac{m_E}{m_M + m_E} d
# \end{align}$$
#
# Since the two large bodies are exactly opposite each other on the orbit around the C.O.M. point, we can write the angle of their motion simply:
#
# $$\begin{align}
# \phi_M &= \omega t \\
# \phi_E &= \omega t + \pi
# \end{align}$$
# with the frequency $\omega = 2\pi/T$.
#
# The satellite feels the forces from both Earth and Moon, so that the differential equations of motions are
#
# $$\begin{align}
# \ddot{x} &= -G m_E \frac{x-x_E}{d_E^3} - G m_M \frac{x-x_M}{d_M^3} \\
# \ddot{y} &= -G m_E \frac{y-y_E}{d_E^3} - G m_M \frac{y-y_M}{d_M^3} \\
# \end{align}$$
#
# We define a **state** of the satellite for our program
# $S = (x, v_x, y, v_y)$, so that we can write a system of 4 first-order differential equations.
#
# $$\begin{align}
# \dot{x} &= v_x \\
# \dot{v_x} &= -G m_E \frac{x-x_E}{d_E^3} - G m_M \frac{x-x_M}{d_M^3} \\
# \dot{y} &= v_y \\
# \dot{v_y} &= -G m_E \frac{y-y_E}{d_E^3} - G m_M \frac{y-y_M}{d_M^3} \\
# \end{align}$$

# %%
# %matplotlib notebook

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.integrate as integrate
import matplotlib.animation as animation

d = 3.844e08 # meters
T = 27.322 * 24. * 3600. # seconds
omega = 2.*np.pi/T
m_earth = 5.976e24 # kilograms
m_moon = 7.35e22 # kilograms
#m_moon = 0
G = 6.67e-11 # N m^2 / kg

def moon_position(t):
    r_moon = m_earth / (m_moon + m_earth) * d
    phi_moon = omega * t
    x_moon = r_moon * np.cos(phi_moon)
    y_moon = r_moon * np.sin(phi_moon)
    return (x_moon, y_moon)
    
def earth_position(t):
    r_earth = m_moon / (m_moon + m_earth) * d
    phi_earth = omega*t + np.pi
    x_earth = r_earth * np.cos(phi_earth)
    y_earth = r_earth * np.sin(phi_earth)
    return (x_earth, y_earth)

def derivs(state, t):
    x = state[0]
    y = state[2]
    out = np.zeros_like(state)
    (x_E, y_E) = earth_position(t)
    (x_M, y_M) = moon_position(t)
    d_E = np.sqrt(pow(x-x_E, 2) + pow(y-y_E, 2))
    d_M = np.sqrt(pow(x-x_M, 2) + pow(y-y_M, 2))
    
    out[0] = state[1]
    out[1] = -G*m_earth*(x-x_E)/pow(d_E,3) - G*m_moon*(x-x_M)/pow(d_M,3)
    out[2] = state[3]
    out[3] = -G*m_earth*(y-y_E)/pow(d_E,3) - G*m_moon*(y-y_M)/pow(d_M,3)
    return out

# create a time array
dt = 50000 # seconds
time_interval = np.arange(0.0, 2*T, dt)
earth_positions = []
moon_positions = []

# state with 4 elements of satellite motion: (x, v_x, y, v_y)
#state = (2e8, 0, 0, 1.5e3) # medium Earth orbit
state = (2e8, 0, 0, 1.6e3) # Moon landing at 3.5e6 s (40 days)

satellite_positions = integrate.odeint(derivs, state, time_interval)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, autoscale_on=False, xlim=(-7e8, 7e8), ylim=(-7e8, 7e8))
ax.grid()

earth_marker, = ax.plot([], [], 'o-', markersize=40)
moon_marker, = ax.plot([], [], 'o-', markersize=20)
satellite_marker, = ax.plot([], [], 'o-', markersize=10)
time_template = 'time = %.0fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

itime = 0
for time in time_interval:
    earth_positions.append(earth_position(time))
    moon_positions.append(moon_position(time))

def init():
    earth_marker.set_data([], [])
    moon_marker.set_data([], [])
    satellite_marker.set_data([], [])
    time_text.set_text('')
    return earth_marker, moon_marker, time_text

def animate(i):
    earth_marker.set_data(earth_positions[i][0], earth_positions[i][1])
    moon_marker.set_data(  moon_positions[i][0],  moon_positions[i][1])
    satellite_marker.set_data(satellite_positions[i,0], satellite_positions[i,2])
    time_text.set_text(time_template % (i*dt))
    return earth_marker, moon_marker, time_text

ani = matplotlib.animation.FuncAnimation(fig, animate, np.arange(1, len(time_interval)),
                                         interval=200, blit=True, init_func=init)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Approaches to Solving ODE
#
# The methods we have been studying require evaluation of the first-order derivatives, so that we know how far to step with our solution at each time step.
# This is fine if the derivatives are known.  (They must be known, since they are the differential equation!)
#
# Those methods give use **the answer** for each time step, and that answer is never revisited in subsequent steps.
# If there is a problem with any single step, so that we get an inaccurate answer, there will be a cumulative build-up of error for all of the subsequent steps.
#
# Now we will look at two new methods for solving ODEs.  These methods use a discrete *finite* set of points or intervals at which the differential equations are solved:
# * **finite difference method**: choose a set of points at which to approximate the derivatives with finite differences
# * **finite element method**: choose a trial function and adjust parameters to minimize the integrated error over a set of intervals (elements)

# %% [markdown]
# # Finite Difference Method
#
# The finite difference method replaces the analytic or functional derivative by a difference.
# In this way, the *differential equation* is replaced by a *difference equation*.
# This method works best if the the derivative is a linear function $f(t, x, x')$.
#
# As an example, let's consider the differential equation in 1 dimension $y$, with $x$ as the independent variable.
# (Sometimes it is good to remember that these methods can work with space intervals as well as time intervals.)
#
# $$\begin{cases}
# \frac{d^2 y}{dx^2} = 5 \frac{dy}{dx} - 10 y(x) + 10x \\
# y(0) = 0 \\
# y(1) = 100
# \end{cases}$$
#
# In order to write some finite difference (usually central-difference) substitutions for the derivatives, we need to define a discrete "grid" of points.
# Here, a convenient grid in 1 dimension might be 11 points $(0.0, 0.1, \dots 0.9, 1.0)$.
# Our new goal will be to find $y_i$ values ($i=1,\dots,9$) for the 9 points inside the interval.
# The $y$ values on the endpoints ($y_0, y_{10}$) are of course fixed by the boundary conditions.
#
# The first step is to approximate the first and second derivatives by the appropriate central-difference and midpoint formulas:
#
# $$\begin{align}
# y_i'(x) &\approx \frac{y_{i+1}-y_{i-1}}{2h} \\
# y_i''(x) &\approx \frac{y_{i+1} - 2y_i + y_{i-1}}{h^2}
# \end{align}$$
#
# Note that the step $h$ is between the discrete grid (mesh) points.  This step may be a step in time or a step along the spatial dimensions.
#
# The second step is to substitute these approximations in the original differential equation to convert it to a finite difference equation:
#
# $$\frac{y_{i+1} - 2y_i + y_{i-1}}{h^2} = 5 \frac{y_{i+1}-y_{i-1}}{2h} - 10 y_i + 10 x_i$$
#
# Now we can solve for $y_i$.  (But remember that we have made approximations in defining a discrete grid and converting the derivatives.)
#
# $$y_i = \frac{1}{2- 10h^2} \left[ \left( 1- \frac{5h}{2} \right) y_{i+1} + \left( 1+ \frac{5h}{2} \right) y_{i-1} - 10h^2 x_i \right]$$
#
# We saw forms like this in our explorations of explicit and implicit methods for ODEs.
# It should be possible to write the equations in linear algebra form (9 equations for 9 unknowns) and solve for $y_i$.
# This particular equation is like the implicit methods because $y_i$ relies on knowledge of $y_{i+1}$.
#
# In practice, these $N-2$ approximate difference equations are usually solved through an **iterative** process, in which the $y_i$ values are updated on successive passes through the grid.
# The idea is that an estimate of $y_i^{(j)}$ on the $j$th iteration through the grid will be updated to $y_i^{(j+1)}$.
#
# $$y_i^{(j)} = \frac{1}{2- 10h^2} \left[ \left( 1- \frac{5h}{2} \right) y_{i+1}^{(j-1)} + \left( 1+ \frac{5h}{2} \right) y_{i-1}^{(j-1)} - 10h^2 x_i \right]$$
#
# Of course, we cannot use the new values of $y_{i+1}^{(j-1)}$ and $y_{i-1}^{(j-1)}$ until we have calculated them!
#
# But if we move from "left to right" ("top to bottom") in the equations for $y_i$, we will know $y_{i-1}^{(j)}$ in time to use it in calculating $y_i^{(j)}$.
# This approach of using the updated values as soon as they become available is known as the **Gauss-Seidel** iteration procedure.
#
# * **Jacobi method**: use only the values from the previous iteration.
#  * Pro: calculation of each $y_i$ can proceed in parallel.
#  * Con: requires two state vectors `old` and `new` to hold $y_i$ values.
# * **Gauss-Seidel method**: use the values from the current iteration when available.
#  * Pro: requires only one state vector, with $y_i$ updated in place.
#  * Con: cannot be parallelized.
#
# When the difference between successive iterations is small enough (compared to some tolerance), we stop the process.
# We cannot stop the process unless the difference is acceptable for **all** $y_i$ values!

# %%
# Jacobi method

N = 11
(x_grid_points, h) = np.linspace(0., 1., 11, retstep=True)
c1 = 1.0 - 2.5*h
c2 = 1.0 + 2.5*h
c3 = -10.0 * pow(h,2)
c4 = 2.0 + c3

old_y_values = np.zeros(N)
old_y_values[0] = 0.
old_y_values[N-1] = 100.
y_values = old_y_values.copy()

tolerance = 0.0001
achieved_tolerance = False
iteration = 0
while (not achieved_tolerance):
    iteration += 1
    achieved_tolerance = True   # until we know otherwise
    for i in range(1,N-1):
        yy = 1./c4 * (c1*old_y_values[i+1] + c2*old_y_values[i-1] + c3*x_grid_points[i])
        if (abs((yy-y_values[i]))/yy > tolerance):
            achieved_tolerance = False
            print('Iteration', iteration, ': Not at tolerance for i =', i)
        y_values[i] = yy
        old_y_values[i] = yy
        
    print(y_values)
# Out:
# Iteration 1 : Not at tolerance for i = 9
# [ 0.00000000e+00 -5.26315789e-03 -1.39889197e-02 -2.49927103e-02
#  -3.74952041e-02 -5.09836869e-02 -6.51208467e-02 -7.96847675e-02
#  -9.45294523e-02  3.93641254e+01  1.00000000e+02]
# Iteration 2 : Not at tolerance for i = 8
# Iteration 2 : Not at tolerance for i = 9
# [ 0.00000000e+00 -1.07850999e-02 -2.74873198e-02 -4.86739752e-02
#  -7.32001232e-02 -1.00179363e-01 -1.28940936e-01 -1.58985926e-01
#   1.53917693e+01  4.95524798e+01  1.00000000e+02]
# Iteration 3 : Not at tolerance for i = 7
# Iteration 3 : Not at tolerance for i = 8
# Iteration 3 : Not at tolerance for i = 9
# [ 0.00000000e+00 -1.61134157e-02 -4.03406584e-02 -7.12241660e-02
#  -1.07455121e-01 -1.47907686e-01 -1.91644238e-01  5.91277456e+00
#   2.34080674e+01  5.48263601e+01  1.00000000e+02]
# Iteration 4 : Not at tolerance for i = 6
# Iteration 4 : Not at tolerance for i = 7
# Iteration 4 : Not at tolerance for i = 8
# Iteration 4 : Not at tolerance for i = 9
# [ 0.00000000e+00 -2.11871020e-02 -5.25800011e-02 -9.27980747e-02
#  -1.40488609e-01 -1.94391547e-01  2.17452183e+00  1.06337910e+01
#   2.85957941e+01  5.82393382e+01  1.00000000e+02]
# Iteration 5 : Not at tolerance for i = 5
# Iteration 5 : Not at tolerance for i = 6
# Iteration 5 : Not at tolerance for i = 7
# Iteration 5 : Not at tolerance for i = 8
# Iteration 5 : Not at tolerance for i = 9
# [ 0.00000000e+00 -2.60184215e-02 -6.42745173e-02 -1.13531370e-01
#  -1.72477828e-01  7.18575836e-01  4.63871738e+00  1.43027591e+01
#   3.23568171e+01  6.07136955e+01  1.00000000e+02]
# Iteration 6 : Not at tolerance for i = 4
# Iteration 6 : Not at tolerance for i = 5
# Iteration 6 : Not at tolerance for i = 6
# Iteration 6 : Not at tolerance for i = 7
# Iteration 6 : Not at tolerance for i = 8
# Iteration 6 : Not at tolerance for i = 9
# [ 0.00000000e+00 -3.06346779e-02 -7.54957237e-02 -1.33541066e-01
#   1.74739760e-01  1.91971723e+00  6.87721888e+00  1.72600718e+01
#   3.52791376e+01  6.26362747e+01  1.00000000e+02]
# Iteration 7 : Not at tolerance for i = 4
# Iteration 7 : Not at tolerance for i = 5
# Iteration 7 : Not at tolerance for i = 6
# Iteration 7 : Not at tolerance for i = 7
# Iteration 7 : Not at tolerance for i = 8
# Iteration 7 : Not at tolerance for i = 9
# [ 0.00000000e+00 -3.50641015e-02 -8.63083824e-02 -3.59508302e-03
#   7.34365299e-01  3.17151094e+00  8.86812765e+00  1.97234278e+01
#   3.76586793e+01  6.42017627e+01  1.00000000e+02]
# Iteration 8 : Not at tolerance for i = 3
# Iteration 8 : Not at tolerance for i = 4
# Iteration 8 : Not at tolerance for i = 5
# Iteration 8 : Not at tolerance for i = 6
# Iteration 8 : Not at tolerance for i = 7
# Iteration 8 : Not at tolerance for i = 8
# Iteration 8 : Not at tolerance for i = 9
# [ 0.00000000e+00 -3.93322562e-02 -3.78219118e-02  2.49208729e-01
#   1.39481269e+00  4.39190084e+00  1.06433931e+01  2.18306583e+01
#   3.96629710e+01  6.55203757e+01  1.00000000e+02]
# Iteration 9 : Not at tolerance for i = 2
# Iteration 9 : Not at tolerance for i = 3
# Iteration 9 : Not at tolerance for i = 4
# Iteration 9 : Not at tolerance for i = 5
# Iteration 9 : Not at tolerance for i = 6
# Iteration 9 : Not at tolerance for i = 7
# Iteration 9 : Not at tolerance for i = 8
# Iteration 9 : Not at tolerance for i = 9
# [ 0.00000000e+00 -2.01928599e-02  7.45607745e-02  5.83847624e-01
#   2.09670272e+00  5.55443327e+00  1.22400186e+01  2.36722376e+01
#   4.13950415e+01  6.66598957e+01  1.00000000e+02]
# Iteration 10 : Not at tolerance for i = 1
# Iteration 10 : Not at tolerance for i = 2
# Iteration 10 : Not at tolerance for i = 3
# Iteration 10 : Not at tolerance for i = 4
# Iteration 10 : Not at tolerance for i = 5
# Iteration 10 : Not at tolerance for i = 6
# Iteration 10 : Not at tolerance for i = 7
# Iteration 10 : Not at tolerance for i = 8
# Iteration 10 : Not at tolerance for i = 9
# [0.00000000e+00 2.41687268e-02 2.35840330e-01 9.67014447e-01
#  2.80768053e+00 6.65242875e+00 1.36893232e+01 2.53094396e+01
#  4.29219585e+01 6.76644464e+01 1.00000000e+02]
# Iteration 11 : Not at tolerance for i = 1
# Iteration 11 : Not at tolerance for i = 2
# Iteration 11 : Not at tolerance for i = 3
# Iteration 11 : Not at tolerance for i = 4
# Iteration 11 : Not at tolerance for i = 5
# Iteration 11 : Not at tolerance for i = 6
# Iteration 11 : Not at tolerance for i = 7
# Iteration 11 : Not at tolerance for i = 8
# Iteration 11 : Not at tolerance for i = 9
# [0.00000000e+00 8.78317092e-02 4.28973933e-01 1.37472517e+00
#  3.50933054e+00 7.68613453e+00 1.50156568e+01 2.67847578e+01
#  4.42890958e+01 6.85638788e+01 1.00000000e+02]
# Iteration 12 : Not at tolerance for i = 1
# Iteration 12 : Not at tolerance for i = 2
# Iteration 12 : Not at tolerance for i = 3
# Iteration 12 : Not at tolerance for i = 4
# Iteration 12 : Not at tolerance for i = 5
# Iteration 12 : Not at tolerance for i = 6
# Iteration 12 : Not at tolerance for i = 7
# Iteration 12 : Not at tolerance for i = 8
# Iteration 12 : Not at tolerance for i = 9
# [  0.           0.16406866   0.64006826   1.79057012   4.1909545
#    8.65812405  16.23748601  28.12825231  45.5280129   69.37895586
#  100.        ]
# Iteration 13 : Not at tolerance for i = 1
# Iteration 13 : Not at tolerance for i = 2
# Iteration 13 : Not at tolerance for i = 3
# Iteration 13 : Not at tolerance for i = 4
# Iteration 13 : Not at tolerance for i = 5
# Iteration 13 : Not at tolerance for i = 6
# Iteration 13 : Not at tolerance for i = 7
# Iteration 13 : Not at tolerance for i = 8
# Iteration 13 : Not at tolerance for i = 9
# [  0.           0.24739537   0.85903779   2.20369111   4.8464247
#    9.57165546  17.3688203   29.36159739  46.66116507  70.1244507
#  100.        ]
# Iteration 14 : Not at tolerance for i = 1
# Iteration 14 : Not at tolerance for i = 2
# Iteration 14 : Not at tolerance for i = 3
# Iteration 14 : Not at tolerance for i = 4
# Iteration 14 : Not at tolerance for i = 5
# Iteration 14 : Not at tolerance for i = 6
# Iteration 14 : Not at tolerance for i = 7
# Iteration 14 : Not at tolerance for i = 8
# Iteration 14 : Not at tolerance for i = 9
# [  0.           0.33383071   1.07897722   2.60712634   5.47244712
#   10.43009164  18.42042768  30.50074127  47.70487611  70.8111027
#  100.        ]
# Iteration 15 : Not at tolerance for i = 1
# Iteration 15 : Not at tolerance for i = 2
# Iteration 15 : Not at tolerance for i = 3
# Iteration 15 : Not at tolerance for i = 4
# Iteration 15 : Not at tolerance for i = 5
# Iteration 15 : Not at tolerance for i = 6
# Iteration 15 : Not at tolerance for i = 7
# Iteration 15 : Not at tolerance for i = 8
# Iteration 15 : Not at tolerance for i = 9
# [  0.           0.4206489    1.2953452    2.99658781   6.06752815
#   11.2367005   19.40075346  31.55768364  48.67127978  71.44689459
#  100.        ]
# Iteration 16 : Not at tolerance for i = 1
# Iteration 16 : Not at tolerance for i = 2
# Iteration 16 : Not at tolerance for i = 3
# Iteration 16 : Not at tolerance for i = 4
# Iteration 16 : Not at tolerance for i = 5
# Iteration 16 : Not at tolerance for i = 6
# Iteration 16 : Not at tolerance for i = 7
# Iteration 16 : Not at tolerance for i = 8
# Iteration 16 : Not at tolerance for i = 9
# [  0.           0.50605732   1.50526974   3.36959647   6.63132682
#   11.99459138  20.31657998  32.54167621  49.56961379  72.03790381
#  100.        ]
# Iteration 17 : Not at tolerance for i = 1
# Iteration 17 : Not at tolerance for i = 2
# Iteration 17 : Not at tolerance for i = 3
# Iteration 17 : Not at tolerance for i = 4
# Iteration 17 : Not at tolerance for i = 5
# Iteration 17 : Not at tolerance for i = 6
# Iteration 17 : Not at tolerance for i = 7
# Iteration 17 : Not at tolerance for i = 8
# Iteration 17 : Not at tolerance for i = 9
# [  0.           0.58892227   1.70702641   3.72488323   7.16423556
#   12.7066997   21.17349041  33.46003861  50.4070927   72.58887677
#  100.        ]
# Iteration 18 : Not at tolerance for i = 1
# Iteration 18 : Not at tolerance for i = 2
# Iteration 18 : Not at tolerance for i = 3
# Iteration 18 : Not at tolerance for i = 4
# Iteration 18 : Not at tolerance for i = 5
# Iteration 18 : Not at tolerance for i = 6
# Iteration 18 : Not at tolerance for i = 7
# Iteration 18 : Not at tolerance for i = 8
# Iteration 18 : Not at tolerance for i = 9
# [  0.           0.66856306   1.89966644   4.0619788    7.66710436
#   13.37578856  21.97619192  34.31871549  51.18950102  73.10361909
#  100.        ]
# Iteration 19 : Not at tolerance for i = 1
# Iteration 19 : Not at tolerance for i = 2
# Iteration 19 : Not at tolerance for i = 3
# Iteration 19 : Not at tolerance for i = 4
# Iteration 19 : Not at tolerance for i = 5
# Iteration 19 : Not at tolerance for i = 6
# Iteration 19 : Not at tolerance for i = 7
# Iteration 19 : Not at tolerance for i = 8
# Iteration 19 : Not at tolerance for i = 9
# [  0.           0.74460517   2.0827582    4.38093474   8.14105781
#   14.0044559   22.72874026  35.12265847  51.92159863  73.58526226
#  100.        ]
# Iteration 20 : Not at tolerance for i = 1
# Iteration 20 : Not at tolerance for i = 2
# Iteration 20 : Not at tolerance for i = 3
# Iteration 20 : Not at tolerance for i = 4
# Iteration 20 : Not at tolerance for i = 5
# Iteration 20 : Not at tolerance for i = 6
# Iteration 20 : Not at tolerance for i = 7
# Iteration 20 : Not at tolerance for i = 8
# Iteration 20 : Not at tolerance for i = 9
# [  0.           0.81687823   2.25620992   4.68213461   8.58737378
#   14.59514338  23.43469636  35.87608917  52.60739903  74.03644673
#  100.        ]
# Iteration 21 : Not at tolerance for i = 1
# Iteration 21 : Not at tolerance for i = 2
# Iteration 21 : Not at tolerance for i = 3
# Iteration 21 : Not at tolerance for i = 4
# Iteration 21 : Not at tolerance for i = 5
# Iteration 21 : Not at tolerance for i = 6
# Iteration 21 : Not at tolerance for i = 7
# Iteration 21 : Not at tolerance for i = 8
# Iteration 21 : Not at tolerance for i = 9
# [  0.           0.88534602   2.4201492    4.96616676   9.00740315
#   15.15014537  24.0972361   36.58268126  53.25036138  74.45944828
#  100.        ]
# Iteration 22 : Not at tolerance for i = 1
# Iteration 22 : Not at tolerance for i = 2
# Iteration 22 : Not at tolerance for i = 3
# Iteration 22 : Not at tolerance for i = 4
# Iteration 22 : Not at tolerance for i = 5
# Iteration 22 : Not at tolerance for i = 6
# Iteration 22 : Not at tolerance for i = 7
# Iteration 22 : Not at tolerance for i = 8
# Iteration 22 : Not at tolerance for i = 9
# [  0.           0.9500589    2.57484142   5.23373902   9.40251726
#   15.67161771  24.71922794  37.24568735  53.85352389  74.85626572
#  100.        ]
# Iteration 23 : Not at tolerance for i = 1
# Iteration 23 : Not at tolerance for i = 2
# Iteration 23 : Not at tolerance for i = 3
# Iteration 23 : Not at tolerance for i = 4
# Iteration 23 : Not at tolerance for i = 5
# Iteration 23 : Not at tolerance for i = 6
# Iteration 23 : Not at tolerance for i = 7
# Iteration 23 : Not at tolerance for i = 8
# Iteration 23 : Not at tolerance for i = 9
# [  0.           1.01112161   2.72063488   5.48562187   9.77407401
#   16.16158604  25.30328845  37.86802815  54.41959709  75.2286823
#  100.        ]
# Iteration 24 : Not at tolerance for i = 1
# Iteration 24 : Not at tolerance for i = 2
# Iteration 24 : Not at tolerance for i = 3
# Iteration 24 : Not at tolerance for i = 4
# Iteration 24 : Not at tolerance for i = 5
# Iteration 24 : Not at tolerance for i = 6
# Iteration 24 : Not at tolerance for i = 7
# Iteration 24 : Not at tolerance for i = 8
# Iteration 24 : Not at tolerance for i = 9
# [  0.           1.06867166   2.8579242    5.72261093  10.12339641
#   16.62195361  25.85182269  38.45235589  54.95102978  75.57830907
#  100.        ]
# Iteration 25 : Not at tolerance for i = 1
# Iteration 25 : Not at tolerance for i = 2
# Iteration 25 : Not at tolerance for i = 3
# Iteration 25 : Not at tolerance for i = 4
# Iteration 25 : Not at tolerance for i = 5
# Iteration 25 : Not at tolerance for i = 6
# Iteration 25 : Not at tolerance for i = 7
# Iteration 25 : Not at tolerance for i = 8
# Iteration 25 : Not at tolerance for i = 9
# [  0.           1.12286482   2.9871259    5.94550247  10.45175963
#   17.05450871  26.36705411  39.00109998  55.4500562   75.90661592
#  100.        ]
# Iteration 26 : Not at tolerance for i = 1
# Iteration 26 : Not at tolerance for i = 2
# Iteration 26 : Not at tolerance for i = 3
# Iteration 26 : Not at tolerance for i = 4
# Iteration 26 : Not at tolerance for i = 5
# Iteration 26 : Not at tolerance for i = 6
# Iteration 26 : Not at tolerance for i = 7
# Iteration 26 : Not at tolerance for i = 8
# Iteration 26 : Not at tolerance for i = 9
# [  0.           1.17386549   3.10866248   6.1550778   10.76038357
#   17.4609316   26.8510471   39.51650054  55.91873032  76.21495416
#  100.        ]
# Iteration 27 : Not at tolerance for i = 1
# Iteration 27 : Not at tolerance for i = 2
# Iteration 27 : Not at tolerance for i = 3
# Iteration 27 : Not at tolerance for i = 4
# Iteration 27 : Not at tolerance for i = 5
# Iteration 27 : Not at tolerance for i = 6
# Iteration 27 : Not at tolerance for i = 7
# Iteration 27 : Not at tolerance for i = 8
# Iteration 27 : Not at tolerance for i = 9
# [  0.           1.22184045   3.22295206   6.35209355  11.05042929
#   17.84280102  27.30572457  40.0006334   56.35895124  76.50457319
#  100.        ]
# Iteration 28 : Not at tolerance for i = 1
# Iteration 28 : Not at tolerance for i = 2
# Iteration 28 : Not at tolerance for i = 3
# Iteration 28 : Not at tolerance for i = 4
# Iteration 28 : Not at tolerance for i = 5
# Iteration 28 : Not at tolerance for i = 6
# Iteration 28 : Not at tolerance for i = 7
# Iteration 28 : Not at tolerance for i = 8
# Iteration 28 : Not at tolerance for i = 9
# [  0.           1.26695476   3.3304019    6.53727597  11.32299775
#   18.20160032  27.73288182  40.45542932  56.77248239  76.77663315
#  100.        ]
# Iteration 29 : Not at tolerance for i = 1
# Iteration 29 : Not at tolerance for i = 2
# Iteration 29 : Not at tolerance for i = 3
# Iteration 29 : Not at tolerance for i = 4
# Iteration 29 : Not at tolerance for i = 5
# Iteration 29 : Not at tolerance for i = 6
# Iteration 29 : Not at tolerance for i = 7
# Iteration 29 : Not at tolerance for i = 8
# Iteration 29 : Not at tolerance for i = 9
# [  0.           1.30936917   3.43140444   6.71131783  11.57913028
#   18.53872327  28.13419793  40.88268906  57.16096641  77.03221474
#  100.        ]
# Iteration 30 : Not at tolerance for i = 1
# Iteration 30 : Not at tolerance for i = 2
# Iteration 30 : Not at tolerance for i = 3
# Iteration 30 : Not at tolerance for i = 4
# Iteration 30 : Not at tolerance for i = 5
# Iteration 30 : Not at tolerance for i = 6
# Iteration 30 : Not at tolerance for i = 7
# Iteration 30 : Not at tolerance for i = 8
# Iteration 30 : Not at tolerance for i = 9
# [  0.           1.3492386    3.52633506   6.87487712  11.81980992
#   18.8554794   28.51124528  41.28409548  57.52593706  77.27232701
#  100.        ]
# Iteration 31 : Not at tolerance for i = 1
# Iteration 31 : Not at tolerance for i = 2
# Iteration 31 : Not at tolerance for i = 3
# Iteration 31 : Not at tolerance for i = 4
# Iteration 31 : Not at tolerance for i = 5
# Iteration 31 : Not at tolerance for i = 6
# Iteration 31 : Not at tolerance for i = 7
# Iteration 31 : Not at tolerance for i = 8
# Iteration 31 : Not at tolerance for i = 9
# [  0.           1.38671121   3.61555097   7.02857693  12.04596353
#   19.15309914  28.86549765  41.66122361  57.86882883  77.4979137
#  100.        ]
# Iteration 32 : Not at tolerance for i = 1
# Iteration 32 : Not at tolerance for i = 2
# Iteration 32 : Not at tolerance for i = 3
# Iteration 32 : Not at tolerance for i = 4
# Iteration 32 : Not at tolerance for i = 5
# Iteration 32 : Not at tolerance for i = 6
# Iteration 32 : Not at tolerance for i = 7
# Iteration 32 : Not at tolerance for i = 8
# Iteration 32 : Not at tolerance for i = 9
# [  0.           1.42192802   3.6993909    7.17300593  12.25846409
#   19.43273861  29.19833735  42.01554911  58.19098509  77.70985861
#  100.        ]
# Iteration 33 : Not at tolerance for i = 1
# Iteration 33 : Not at tolerance for i = 2
# Iteration 33 : Not at tolerance for i = 3
# Iteration 33 : Not at tolerance for i = 4
# Iteration 33 : Not at tolerance for i = 5
# Iteration 33 : Not at tolerance for i = 6
# Iteration 33 : Not at tolerance for i = 7
# Iteration 33 : Not at tolerance for i = 8
# Iteration 33 : Not at tolerance for i = 9
# [  0.           1.45502272   3.77817519   7.3087195   12.45813333
#   19.69548404  29.51106152  42.34845564  58.493665    77.90899013
#  100.        ]
# Iteration 34 : Not at tolerance for i = 1
# Iteration 34 : Not at tolerance for i = 2
# Iteration 34 : Not at tolerance for i = 3
# Iteration 34 : Not at tolerance for i = 4
# Iteration 34 : Not at tolerance for i = 5
# Iteration 34 : Not at tolerance for i = 6
# Iteration 34 : Not at tolerance for i = 7
# Iteration 34 : Not at tolerance for i = 8
# Iteration 34 : Not at tolerance for i = 9
# [  0.           1.48612178   3.85220624   7.43624095  12.64574432
#   19.94235608  29.8048878   42.66124132  58.7780496   78.09608527
#  100.        ]
# Iteration 35 : Not at tolerance for i = 1
# Iteration 35 : Not at tolerance for i = 2
# Iteration 35 : Not at tolerance for i = 3
# Iteration 35 : Not at tolerance for i = 4
# Iteration 35 : Not at tolerance for i = 5
# Iteration 35 : Not at tolerance for i = 6
# Iteration 35 : Not at tolerance for i = 7
# Iteration 35 : Not at tolerance for i = 8
# Iteration 35 : Not at tolerance for i = 9
# [  0.           1.51534457   3.92176917   7.556063    12.82202411
#   20.17431368  30.08095952  42.95512453  59.04524716  78.27187313
#  100.        ]
# Iteration 36 : Not at tolerance for i = 1
# Iteration 36 : Not at tolerance for i = 2
# Iteration 36 : Not at tolerance for i = 3
# Iteration 36 : Not at tolerance for i = 4
# Iteration 36 : Not at tolerance for i = 5
# Iteration 36 : Not at tolerance for i = 6
# Iteration 36 : Not at tolerance for i = 7
# Iteration 36 : Not at tolerance for i = 8
# Iteration 36 : Not at tolerance for i = 9
# [  0.           1.54280362   3.98713251   7.66864933  12.98765627
#   20.39225789  30.3403504   43.23124914  59.29629804  78.43703818
#  100.        ]
# Iteration 37 : Not at tolerance for i = 1
# Iteration 37 : Not at tolerance for i = 2
# Iteration 37 : Not at tolerance for i = 3
# Iteration 37 : Not at tolerance for i = 4
# Iteration 37 : Not at tolerance for i = 5
# Iteration 37 : Not at tolerance for i = 6
# Iteration 37 : Not at tolerance for i = 7
# Iteration 37 : Not at tolerance for i = 8
# Iteration 37 : Not at tolerance for i = 9
# [  0.           1.56860494   4.04854904   7.77443605  13.14328341
#   20.5970353   30.58406893  43.49068931  59.5321791   78.59222309
#  100.        ]
# Iteration 38 : Not at tolerance for i = 1
# Iteration 38 : Not at tolerance for i = 2
# Iteration 38 : Not at tolerance for i = 3
# Iteration 38 : Not at tolerance for i = 4
# Iteration 38 : Not at tolerance for i = 5
# Iteration 38 : Not at tolerance for i = 6
# Iteration 38 : Not at tolerance for i = 7
# Iteration 38 : Not at tolerance for i = 8
# Iteration 38 : Not at tolerance for i = 9
# [  0.           1.5928483    4.10625654   7.87383328  13.28950951
#   20.78944136  30.81306247  43.7344539   59.75380773  78.7380314
#  100.        ]
# Iteration 39 : Not at tolerance for i = 1
# Iteration 39 : Not at tolerance for i = 2
# Iteration 39 : Not at tolerance for i = 3
# Iteration 39 : Not at tolerance for i = 4
# Iteration 39 : Not at tolerance for i = 5
# Iteration 39 : Not at tolerance for i = 6
# Iteration 39 : Not at tolerance for i = 7
# Iteration 39 : Not at tolerance for i = 8
# Iteration 39 : Not at tolerance for i = 9
# [  0.           1.61562758   4.16047865   7.96722655  13.42690222
#   20.97022348  31.02822094  43.96349051  59.96204563  78.87503002
#  100.        ]
# Iteration 40 : Not at tolerance for i = 1
# Iteration 40 : Not at tolerance for i = 2
# Iteration 40 : Not at tolerance for i = 3
# Iteration 40 : Not at tolerance for i = 4
# Iteration 40 : Not at tolerance for i = 5
# Iteration 40 : Not at tolerance for i = 6
# Iteration 40 : Not at tolerance for i = 7
# Iteration 40 : Not at tolerance for i = 8
# Iteration 40 : Not at tolerance for i = 9
# [  0.           1.63703105   4.21142564   8.05497827  13.55599497
#   21.14008391  31.2303804   44.17868933  60.1577022   79.00375144
#  100.        ]
# Iteration 41 : Not at tolerance for i = 1
# Iteration 41 : Not at tolerance for i = 2
# Iteration 41 : Not at tolerance for i = 3
# Iteration 41 : Not at tolerance for i = 4
# Iteration 41 : Not at tolerance for i = 5
# Iteration 41 : Not at tolerance for i = 6
# Iteration 41 : Not at tolerance for i = 7
# Iteration 41 : Not at tolerance for i = 8
# Iteration 41 : Not at tolerance for i = 9
# [  0.           1.6571417    4.25929517   8.13742905  13.67728908
#   21.29968245  31.42032634  44.38088662  60.34153782  79.12469593
#  100.        ]
# Iteration 42 : Not at tolerance for i = 1
# Iteration 42 : Not at tolerance for i = 2
# Iteration 42 : Not at tolerance for i = 3
# Iteration 42 : Not at tolerance for i = 4
# Iteration 42 : Not at tolerance for i = 5
# Iteration 42 : Not at tolerance for i = 6
# Iteration 42 : Not at tolerance for i = 7
# Iteration 42 : Not at tolerance for i = 8
# Iteration 42 : Not at tolerance for i = 9
# [  0.           1.67603757   4.30427303   8.21489899  13.79125557
#   21.44963906  31.59879673  44.57086804  60.51426684  79.23833345
#  100.        ]
# Iteration 43 : Not at tolerance for i = 1
# Iteration 43 : Not at tolerance for i = 2
# Iteration 43 : Not at tolerance for i = 3
# Iteration 43 : Not at tolerance for i = 4
# Iteration 43 : Not at tolerance for i = 5
# Iteration 43 : Not at tolerance for i = 6
# Iteration 43 : Not at tolerance for i = 7
# Iteration 43 : Not at tolerance for i = 8
# Iteration 43 : Not at tolerance for i = 9
# [  0.           1.69379198   4.3465338    8.28768891  13.89833707
#   21.59053626  31.76648492  44.74937173  60.67656039  79.34510552
#  100.        ]
# Iteration 44 : Not at tolerance for i = 1
# Iteration 44 : Not at tolerance for i = 2
# Iteration 44 : Not at tolerance for i = 3
# Iteration 44 : Not at tolerance for i = 4
# Iteration 44 : Not at tolerance for i = 5
# Iteration 44 : Not at tolerance for i = 6
# Iteration 44 : Not at tolerance for i = 7
# Iteration 44 : Not at tolerance for i = 8
# Iteration 44 : Not at tolerance for i = 9
# [  0.           1.71047387   4.38624159   8.35608147  13.99894949
#   21.72292134  31.92404236  44.91709118  60.82904901  79.44542698
#  100.        ]
# Iteration 45 : Not at tolerance for i = 1
# Iteration 45 : Not at tolerance for i = 2
# Iteration 45 : Not at tolerance for i = 3
# Iteration 45 : Not at tolerance for i = 4
# Iteration 45 : Not at tolerance for i = 5
# Iteration 45 : Not at tolerance for i = 6
# Iteration 45 : Not at tolerance for i = 7
# Iteration 45 : Not at tolerance for i = 8
# Iteration 45 : Not at tolerance for i = 9
# [  0.           1.726148     4.42355058   8.42034228  14.09348361
#   21.84730857  32.0720811   45.07467797  60.9723251   79.53968757
#  100.        ]
# Iteration 46 : Not at tolerance for i = 1
# Iteration 46 : Not at tolerance for i = 2
# Iteration 46 : Not at tolerance for i = 3
# Iteration 46 : Not at tolerance for i = 4
# Iteration 46 : Not at tolerance for i = 5
# Iteration 46 : Not at tolerance for i = 6
# Iteration 46 : Not at tolerance for i = 7
# Iteration 46 : Not at tolerance for i = 8
# Iteration 46 : Not at tolerance for i = 9
# [  0.           1.74087523   4.45860566   8.48072094  14.18230663
#   21.96418111  32.21117624  45.22274428  61.10694528  79.62825347
#  100.        ]
# Iteration 47 : Not at tolerance for i = 1
# Iteration 47 : Not at tolerance for i = 2
# Iteration 47 : Not at tolerance for i = 3
# Iteration 47 : Not at tolerance for i = 4
# Iteration 47 : Not at tolerance for i = 5
# Iteration 47 : Not at tolerance for i = 6
# Iteration 47 : Not at tolerance for i = 7
# Iteration 47 : Not at tolerance for i = 8
# Iteration 47 : Not at tolerance for i = 9
# [  0.           1.75471276   4.49154297   8.53745194  14.26576356
#   22.07399296  32.34186811  45.36186531  61.2334325   79.71146875
#  100.        ]
# Iteration 48 : Not at tolerance for i = 1
# Iteration 48 : Not at tolerance for i = 2
# Iteration 48 : Not at tolerance for i = 3
# Iteration 48 : Not at tolerance for i = 4
# Iteration 48 : Not at tolerance for i = 5
# Iteration 48 : Not at tolerance for i = 6
# Iteration 48 : Not at tolerance for i = 7
# Iteration 48 : Not at tolerance for i = 8
# Iteration 48 : Not at tolerance for i = 9
# [  0.           1.76771433   4.52249046   8.59075565  14.34417857
#   22.17717069  32.46466439  45.49258151  61.35227813  79.78965666
#  100.        ]
# Iteration 49 : Not at tolerance for i = 1
# Iteration 49 : Not at tolerance for i = 2
# Iteration 49 : Not at tolerance for i = 3
# Iteration 49 : Not at tolerance for i = 4
# Iteration 49 : Not at tolerance for i = 5
# Iteration 49 : Not at tolerance for i = 6
# Iteration 49 : Not at tolerance for i = 7
# Iteration 49 : Not at tolerance for i = 8
# Iteration 49 : Not at tolerance for i = 9
# [  0.           1.77993044   4.55156831   8.64083912  14.41785627
#   22.27411507  32.58004209  45.61540063  61.46394384  79.86312095
#  100.        ]
# Iteration 50 : Not at tolerance for i = 1
# Iteration 50 : Not at tolerance for i = 2
# Iteration 50 : Not at tolerance for i = 3
# Iteration 50 : Not at tolerance for i = 4
# Iteration 50 : Not at tolerance for i = 5
# Iteration 50 : Not at tolerance for i = 6
# Iteration 50 : Not at tolerance for i = 7
# Iteration 50 : Not at tolerance for i = 8
# Iteration 50 : Not at tolerance for i = 9
# [  0.           1.79140854   4.57888948   8.68789687  14.48708284
#   22.36520269  32.68844939  45.7307998   61.5688634   79.93214697
#  100.        ]
# Iteration 51 : Not at tolerance for i = 1
# Iteration 51 : Not at tolerance for i = 2
# Iteration 51 : Not at tolerance for i = 3
# Iteration 51 : Not at tolerance for i = 4
# Iteration 51 : Not at tolerance for i = 5
# Iteration 51 : Not at tolerance for i = 6
# Iteration 51 : Not at tolerance for i = 7
# Iteration 51 : Not at tolerance for i = 8
# Iteration 51 : Not at tolerance for i = 9
# [  0.           1.80219322   4.60456009   8.73211171  14.55212718
#   22.45078738  32.79030741  45.83922727  61.66744437  79.99700288
#  100.        ]
# Iteration 52 : Not at tolerance for i = 1
# Iteration 52 : Not at tolerance for i = 2
# Iteration 52 : Not at tolerance for i = 3
# Iteration 52 : Not at tolerance for i = 4
# Iteration 52 : Not at tolerance for i = 5
# Iteration 52 : Not at tolerance for i = 6
# Iteration 52 : Not at tolerance for i = 7
# Iteration 52 : Not at tolerance for i = 8
# Iteration 52 : Not at tolerance for i = 9
# [  0.           1.81232635   4.62867985   8.77365537  14.61324197
#   22.53120159  32.88601181  45.94110423  61.76006971  80.0579406
#  100.        ]
# Iteration 53 : Not at tolerance for i = 1
# Iteration 53 : Not at tolerance for i = 2
# Iteration 53 : Not at tolerance for i = 3
# Iteration 53 : Not at tolerance for i = 4
# Iteration 53 : Not at tolerance for i = 5
# Iteration 53 : Not at tolerance for i = 6
# Iteration 53 : Not at tolerance for i = 7
# Iteration 53 : Not at tolerance for i = 8
# Iteration 53 : Not at tolerance for i = 9
# [  0.           1.82184731   4.65134246   8.81268924  14.6706646
#   22.60675769  32.97593436  46.03682644  61.84709921  80.11519685
#  100.        ]
# Iteration 54 : Not at tolerance for i = 1
# Iteration 54 : Not at tolerance for i = 2
# Iteration 54 : Not at tolerance for i = 3
# Iteration 54 : Not at tolerance for i = 4
# Iteration 54 : Not at tolerance for i = 5
# Iteration 54 : Not at tolerance for i = 6
# Iteration 54 : Not at tolerance for i = 7
# Iteration 54 : Not at tolerance for i = 8
# Iteration 54 : Not at tolerance for i = 9
# [  0.           1.83079307   4.67263593   8.84936493  14.72461812
#   22.67774917  33.06042436  46.12676572  61.92887094  80.16899404
#  100.        ]
# Iteration 55 : Not at tolerance for i = 1
# Iteration 55 : Not at tolerance for i = 2
# Iteration 55 : Not at tolerance for i = 3
# Iteration 55 : Not at tolerance for i = 4
# Iteration 55 : Not at tolerance for i = 5
# Iteration 55 : Not at tolerance for i = 6
# Iteration 55 : Not at tolerance for i = 7
# Iteration 55 : Not at tolerance for i = 8
# Iteration 55 : Not at tolerance for i = 9
# [  0.           1.83919839   4.69264299   8.88382491  14.77531211
#   22.7444518   33.13981002  46.21127143  62.00570254  80.21954114
#  100.        ]
# Iteration 56 : Not at tolerance for i = 1
# Iteration 56 : Not at tolerance for i = 2
# Iteration 56 : Not at tolerance for i = 3
# Iteration 56 : Not at tolerance for i = 4
# Iteration 56 : Not at tolerance for i = 5
# Iteration 56 : Not at tolerance for i = 6
# Iteration 56 : Not at tolerance for i = 7
# Iteration 56 : Not at tolerance for i = 8
# Iteration 56 : Not at tolerance for i = 9
# [  0.           1.84709592   4.71144136   8.91620304  14.8229435
#   22.80712468  33.2143997   46.29067185  62.07789246  80.26703451
#  100.        ]
# Iteration 57 : Not at tolerance for i = 1
# Iteration 57 : Not at tolerance for i = 2
# Iteration 57 : Not at tolerance for i = 3
# Iteration 57 : Not at tolerance for i = 4
# Iteration 57 : Not at tolerance for i = 5
# Iteration 57 : Not at tolerance for i = 6
# Iteration 57 : Not at tolerance for i = 7
# Iteration 57 : Not at tolerance for i = 8
# Iteration 57 : Not at tolerance for i = 9
# [  0.           1.85451633   4.72910405   8.9466251   14.86769731
#   22.86601127  33.28448314  46.36527541  62.14572113  80.31165864
#  100.        ]
# Iteration 58 : Not at tolerance for i = 1
# Iteration 58 : Not at tolerance for i = 2
# Iteration 58 : Not at tolerance for i = 3
# Iteration 58 : Not at tolerance for i = 4
# Iteration 58 : Not at tolerance for i = 5
# Iteration 58 : Not at tolerance for i = 6
# Iteration 58 : Not at tolerance for i = 7
# Iteration 58 : Not at tolerance for i = 8
# Iteration 58 : Not at tolerance for i = 9
# [  0.           1.86148844   4.74569967   8.97520925  14.90974737
#   22.9213403   33.3503326   46.43537189  62.20945202  80.35358686
#  100.        ]
# Iteration 59 : Not at tolerance for i = 1
# Iteration 59 : Not at tolerance for i = 2
# Iteration 59 : Not at tolerance for i = 3
# Iteration 59 : Not at tolerance for i = 4
# Iteration 59 : Not at tolerance for i = 5
# Iteration 59 : Not at tolerance for i = 6
# Iteration 59 : Not at tolerance for i = 7
# Iteration 59 : Not at tolerance for i = 8
# Iteration 59 : Not at tolerance for i = 9
# [  0.           1.86803934   4.76129269   9.00206652  14.94925704
#   22.97332671  33.41220384  46.50123359  62.2693327   80.39298204
#  100.        ]
# Iteration 60 : Not at tolerance for i = 1
# Iteration 60 : Not at tolerance for i = 2
# Iteration 60 : Not at tolerance for i = 3
# Iteration 60 : Not at tolerance for i = 4
# Iteration 60 : Not at tolerance for i = 5
# Iteration 60 : Not at tolerance for i = 6
# Iteration 60 : Not at tolerance for i = 7
# Iteration 60 : Not at tolerance for i = 8
# Iteration 60 : Not at tolerance for i = 9
# [  0.           1.87419448   4.77594368   9.02730125  14.98637979
#   23.02217243  33.47033723  46.56311635  62.32559577  80.42999722
#  100.        ]
# Iteration 61 : Not at tolerance for i = 1
# Iteration 61 : Not at tolerance for i = 2
# Iteration 61 : Not at tolerance for i = 3
# Iteration 61 : Not at tolerance for i = 4
# Iteration 61 : Not at tolerance for i = 5
# Iteration 61 : Not at tolerance for i = 6
# Iteration 61 : Not at tolerance for i = 7
# Iteration 61 : Not at tolerance for i = 8
# Iteration 61 : Not at tolerance for i = 9
# [  0.           1.87997777   4.78970955   9.05101147  15.02125982
#   23.06806721  33.52495856  46.62126054  62.37845979  80.46477617
#  100.        ]
# Iteration 62 : Not at tolerance for i = 1
# Iteration 62 : Not at tolerance for i = 2
# Iteration 62 : Not at tolerance for i = 3
# Iteration 62 : Not at tolerance for i = 4
# Iteration 62 : Not at tolerance for i = 5
# Iteration 62 : Not at tolerance for i = 6
# Iteration 62 : Not at tolerance for i = 7
# Iteration 62 : Not at tolerance for i = 8
# Iteration 62 : Not at tolerance for i = 9
# [  0.           1.88541167   4.80264378   9.07328926  15.05403262
#   23.11118931  33.57628003  46.67589204  62.42813009  80.49745401
#  100.        ]
# Iteration 63 : Not at tolerance for i = 1
# Iteration 63 : Not at tolerance for i = 2
# Iteration 63 : Not at tolerance for i = 3
# Iteration 63 : Not at tolerance for i = 4
# Iteration 63 : Not at tolerance for i = 5
# Iteration 63 : Not at tolerance for i = 6
# Iteration 63 : Not at tolerance for i = 7
# Iteration 63 : Not at tolerance for i = 8
# Iteration 63 : Not at tolerance for i = 9
# [  0.           1.89051728   4.8147966    9.09422117  15.0848255
#   23.15170626  33.62450097  46.72722305  62.47479964  80.52815766
#  100.        ]
# Iteration 64 : Not at tolerance for i = 1
# Iteration 64 : Not at tolerance for i = 2
# Iteration 64 : Not at tolerance for i = 3
# Iteration 64 : Not at tolerance for i = 4
# Iteration 64 : Not at tolerance for i = 5
# Iteration 64 : Not at tolerance for i = 6
# Iteration 64 : Not at tolerance for i = 7
# Iteration 64 : Not at tolerance for i = 8
# Iteration 64 : Not at tolerance for i = 9
# [  0.           1.89531445   4.82621523   9.11388851  15.11375807
#   23.18977543  33.66980872  46.77545296  62.51864971  80.55700639
#  100.        ]
# Iteration 65 : Not at tolerance for i = 1
# Iteration 65 : Not at tolerance for i = 2
# Iteration 65 : Not at tolerance for i = 3
# Iteration 65 : Not at tolerance for i = 4
# Iteration 65 : Not at tolerance for i = 5
# Iteration 65 : Not at tolerance for i = 6
# Iteration 65 : Not at tolerance for i = 7
# Iteration 65 : Not at tolerance for i = 8
# Iteration 65 : Not at tolerance for i = 9
# [  0.           1.8998218    4.83694402   9.13236767  15.14094271
#   23.2255447   33.71237926  46.82076914  62.55985064  80.58411226
#  100.        ]
# Iteration 66 : Not at tolerance for i = 1
# Iteration 66 : Not at tolerance for i = 2
# Iteration 66 : Not at tolerance for i = 3
# Iteration 66 : Not at tolerance for i = 4
# Iteration 66 : Not at tolerance for i = 5
# Iteration 66 : Not at tolerance for i = 6
# Iteration 66 : Not at tolerance for i = 7
# Iteration 66 : Not at tolerance for i = 8
# Iteration 66 : Not at tolerance for i = 9
# [  0.           1.90405685   4.84702464   9.14973044  15.16648504
#   23.25915302  33.75237797  46.8633476   62.59856247  80.60958057
#  100.        ]
# Iteration 67 : Not at tolerance for i = 1
# Iteration 67 : Not at tolerance for i = 2
# Iteration 67 : Not at tolerance for i = 3
# Iteration 67 : Not at tolerance for i = 4
# Iteration 67 : Not at tolerance for i = 5
# Iteration 67 : Not at tolerance for i = 6
# Iteration 67 : Not at tolerance for i = 7
# Iteration 67 : Not at tolerance for i = 8
# Iteration 67 : Not at tolerance for i = 9
# [  0.           1.90803604   4.85649625   9.16604426  15.19048426
#   23.29073095  33.7899602   46.90335374  62.63493558  80.63351025
#  100.        ]
# Iteration 68 : Not at tolerance for i = 1
# Iteration 68 : Not at tolerance for i = 2
# Iteration 68 : Not at tolerance for i = 3
# Iteration 68 : Not at tolerance for i = 4
# Iteration 68 : Not at tolerance for i = 5
# Iteration 68 : Not at tolerance for i = 6
# Iteration 68 : Not at tolerance for i = 7
# Iteration 68 : Not at tolerance for i = 8
# Iteration 68 : Not at tolerance for i = 9
# [  0.           1.91177484   4.86539565   9.18137251  15.2130336
#   23.32040113  33.82527196  46.94094296  62.66911126  80.65599425
#  100.        ]
# Iteration 69 : Not at tolerance for i = 1
# Iteration 69 : Not at tolerance for i = 2
# Iteration 69 : Not at tolerance for i = 3
# Iteration 69 : Not at tolerance for i = 4
# Iteration 69 : Not at tolerance for i = 5
# Iteration 69 : Not at tolerance for i = 6
# Iteration 69 : Not at tolerance for i = 7
# Iteration 69 : Not at tolerance for i = 8
# Iteration 69 : Not at tolerance for i = 9
# [  0.           1.91528776   4.87375741   9.19577472  15.23422066
#   23.34827884  33.8584504   46.97626129  62.70122226  80.67711991
#  100.        ]
# Iteration 70 : Not at tolerance for i = 1
# Iteration 70 : Not at tolerance for i = 2
# Iteration 70 : Not at tolerance for i = 3
# Iteration 70 : Not at tolerance for i = 4
# Iteration 70 : Not at tolerance for i = 5
# Iteration 70 : Not at tolerance for i = 6
# Iteration 70 : Not at tolerance for i = 7
# Iteration 70 : Not at tolerance for i = 8
# Iteration 70 : Not at tolerance for i = 9
# [  0.           1.91858845   4.881614     9.20930684  15.25412772
#   23.37447235  33.88962442  47.00944591  62.73139332  80.69696929
#  100.        ]
# Iteration 71 : Not at tolerance for i = 1
# Iteration 71 : Not at tolerance for i = 2
# Iteration 71 : Not at tolerance for i = 3
# Iteration 71 : Not at tolerance for i = 4
# Iteration 71 : Not at tolerance for i = 5
# Iteration 71 : Not at tolerance for i = 6
# Iteration 71 : Not at tolerance for i = 7
# Iteration 71 : Not at tolerance for i = 8
# Iteration 71 : Not at tolerance for i = 9
# [  0.           1.92168974   4.88899595   9.22202144  15.27283213
#   23.39908341  33.9189151   47.04062572  62.75974164  80.7156195
#  100.        ]
# Iteration 72 : Not at tolerance for i = 1
# Iteration 72 : Not at tolerance for i = 2
# Iteration 72 : Not at tolerance for i = 3
# Iteration 72 : Not at tolerance for i = 4
# Iteration 72 : Not at tolerance for i = 5
# Iteration 72 : Not at tolerance for i = 6
# Iteration 72 : Not at tolerance for i = 7
# Iteration 72 : Not at tolerance for i = 8
# Iteration 72 : Not at tolerance for i = 9
# [  0.           1.92460366   4.89593192   9.2339679   15.29040654
#   23.42220763  33.94643623  47.06992185  62.78637734  80.73314299
#  100.        ]
# Iteration 73 : Not at tolerance for i = 1
# Iteration 73 : Not at tolerance for i = 2
# Iteration 73 : Not at tolerance for i = 3
# Iteration 73 : Not at tolerance for i = 4
# Iteration 73 : Not at tolerance for i = 5
# Iteration 73 : Not at tolerance for i = 6
# Iteration 73 : Not at tolerance for i = 7
# Iteration 73 : Not at tolerance for i = 8
# Iteration 73 : Not at tolerance for i = 9
# [  0.           1.92734155   4.90244887   9.24519263  15.30691922
#   23.44393484  33.9722947   47.0974481   62.81140387  80.74960781
#  100.        ]
# Iteration 74 : Not at tolerance for i = 1
# Iteration 74 : Not at tolerance for i = 2
# Iteration 74 : Not at tolerance for i = 3
# Iteration 74 : Not at tolerance for i = 4
# Iteration 74 : Not at tolerance for i = 5
# Iteration 74 : Not at tolerance for i = 6
# Iteration 74 : Not at tolerance for i = 7
# Iteration 74 : Not at tolerance for i = 8
# Iteration 74 : Not at tolerance for i = 9
# [  0.           1.92991403   4.90857211   9.25573924  15.3224343
#   23.46434942  33.99659098  47.12331138  62.83491847  80.76507794
#  100.        ]
# Iteration 75 : Not at tolerance for i = 1
# Iteration 75 : Not at tolerance for i = 2
# Iteration 75 : Not at tolerance for i = 3
# Iteration 75 : Not at tolerance for i = 4
# Iteration 75 : Not at tolerance for i = 5
# Iteration 75 : Not at tolerance for i = 6
# Iteration 75 : Not at tolerance for i = 7
# Iteration 75 : Not at tolerance for i = 8
# Iteration 75 : Not at tolerance for i = 9
# [  0.           1.9323311    4.91432542   9.26564869  15.33701207
#   23.48353069  34.01941942  47.14761217  62.85701246  80.77961346
#  100.        ]
# Iteration 76 : Not at tolerance for i = 1
# Iteration 76 : Not at tolerance for i = 2
# Iteration 76 : Not at tolerance for i = 3
# Iteration 76 : Not at tolerance for i = 4
# Iteration 76 : Not at tolerance for i = 5
# Iteration 76 : Not at tolerance for i = 6
# Iteration 76 : Not at tolerance for i = 7
# Iteration 76 : Not at tolerance for i = 8
# Iteration 76 : Not at tolerance for i = 9
# [  0.           1.93460214   4.91973115   9.27495947  15.35070913
#   23.50155315  34.04086872  47.17044486  62.87777167  80.79327084
#  100.        ]
# Iteration 77 : Not at tolerance for i = 1
# Iteration 77 : Not at tolerance for i = 2
# Iteration 77 : Not at tolerance for i = 3
# Iteration 77 : Not at tolerance for i = 4
# Iteration 77 : Not at tolerance for i = 5
# Iteration 77 : Not at tolerance for i = 6
# Iteration 77 : Not at tolerance for i = 7
# Iteration 77 : Not at tolerance for i = 8
# Iteration 77 : Not at tolerance for i = 9
# [  0.           1.93673598   4.9248103    9.28370775  15.36357871
#   23.5184868   34.06102219  47.19189815  62.89727674  80.80610312
#  100.        ]
# Iteration 78 : Not at tolerance for i = 1
# Iteration 78 : Not at tolerance for i = 2
# Iteration 78 : Not at tolerance for i = 3
# Iteration 78 : Not at tolerance for i = 4
# Iteration 78 : Not at tolerance for i = 5
# Iteration 78 : Not at tolerance for i = 6
# Iteration 78 : Not at tolerance for i = 7
# Iteration 78 : Not at tolerance for i = 8
# Iteration 78 : Not at tolerance for i = 9
# [  0.           1.93874091   4.92958261   9.29192752  15.37567079
#   23.53439744  34.07995811  47.21205537  62.91560345  80.81816016
#  100.        ]
# Iteration 79 : Not at tolerance for i = 1
# Iteration 79 : Not at tolerance for i = 2
# Iteration 79 : Not at tolerance for i = 3
# Iteration 79 : Not at tolerance for i = 4
# Iteration 79 : Not at tolerance for i = 5
# Iteration 79 : Not at tolerance for i = 6
# Iteration 79 : Not at tolerance for i = 7
# Iteration 79 : Not at tolerance for i = 8
# Iteration 79 : Not at tolerance for i = 9
# [  0.           1.94062471   4.9340666    9.2996507   15.38703235
#   23.54934685  34.09775005  47.23099481  62.93282297  80.82948879
#  100.        ]
# Iteration 80 : Not at tolerance for i = 1
# Iteration 80 : Not at tolerance for i = 2
# Iteration 80 : Not at tolerance for i = 3
# Iteration 80 : Not at tolerance for i = 4
# Iteration 80 : Not at tolerance for i = 5
# Iteration 80 : Not at tolerance for i = 6
# Iteration 80 : Not at tolerance for i = 7
# Iteration 80 : Not at tolerance for i = 8
# Iteration 80 : Not at tolerance for i = 9
# [  0.           1.94239471   4.93827969   9.3069073   15.39770751
#   23.56339312  34.11446711  47.24879006  62.94900219  80.84013302
#  100.        ]
# Iteration 81 : Not at tolerance for i = 1
# Iteration 81 : Not at tolerance for i = 2
# Iteration 81 : Not at tolerance for i = 3
# Iteration 81 : Not at tolerance for i = 4
# Iteration 81 : Not at tolerance for i = 5
# Iteration 81 : Not at tolerance for i = 6
# Iteration 81 : Not at tolerance for i = 7
# Iteration 81 : Not at tolerance for i = 8
# Iteration 81 : Not at tolerance for i = 9
# [  0.           1.94405777   4.94223826   9.3137255   15.40773775
#   23.5765908   34.13017423  47.26551023  62.96420397  80.85013419
#  100.        ]
# Iteration 82 : Not at tolerance for i = 1
# Iteration 82 : Not at tolerance for i = 2
# Iteration 82 : Not at tolerance for i = 3
# Iteration 82 : Not at tolerance for i = 4
# Iteration 82 : Not at tolerance for i = 5
# Iteration 82 : Not at tolerance for i = 6
# Iteration 82 : Not at tolerance for i = 7
# Iteration 82 : Not at tolerance for i = 8
# Iteration 82 : Not at tolerance for i = 9
# [  0.           1.94562037   4.94595768   9.32013179  15.41716202
#   23.58899116  34.14493243  47.28122027  62.97848736  80.85953116
#  100.        ]
# Iteration 83 : Not at tolerance for i = 1
# Iteration 83 : Not at tolerance for i = 2
# Iteration 83 : Not at tolerance for i = 3
# Iteration 83 : Not at tolerance for i = 4
# Iteration 83 : Not at tolerance for i = 5
# Iteration 83 : Not at tolerance for i = 6
# Iteration 83 : Not at tolerance for i = 7
# Iteration 83 : Not at tolerance for i = 8
# Iteration 83 : Not at tolerance for i = 9
# [  0.           1.94708856   4.94945239   9.32615105  15.42601694
#   23.60064237  34.15879903  47.29598122  62.99190784  80.86836042
#  100.        ]
# Iteration 84 : Not at tolerance for i = 1
# Iteration 84 : Not at tolerance for i = 2
# Iteration 84 : Not at tolerance for i = 3
# Iteration 84 : Not at tolerance for i = 4
# Iteration 84 : Not at tolerance for i = 5
# Iteration 84 : Not at tolerance for i = 6
# Iteration 84 : Not at tolerance for i = 7
# Iteration 84 : Not at tolerance for i = 8
# Iteration 84 : Not at tolerance for i = 9
# [  0.           1.94846805   4.95273597   9.33180667  15.4343369
#   23.61158968  34.1718279   47.3098504   63.00451753  80.87665627
#  100.        ]
# Iteration 85 : Not at tolerance for i = 1
# Iteration 85 : Not at tolerance for i = 2
# Iteration 85 : Not at tolerance for i = 3
# Iteration 85 : Not at tolerance for i = 4
# Iteration 85 : Not at tolerance for i = 5
# Iteration 85 : Not at tolerance for i = 6
# Iteration 85 : Not at tolerance for i = 7
# Iteration 85 : Not at tolerance for i = 8
# [  0.           1.9497642    4.95582119   9.33712061  15.44215422
#   23.62187564  34.18406965  47.32288169  63.01636543  80.88445094
#  100.        ]
# Iteration 86 : Not at tolerance for i = 1
# Iteration 86 : Not at tolerance for i = 2
# Iteration 86 : Not at tolerance for i = 3
# Iteration 86 : Not at tolerance for i = 4
# Iteration 86 : Not at tolerance for i = 5
# Iteration 86 : Not at tolerance for i = 6
# Iteration 86 : Not at tolerance for i = 7
# Iteration 86 : Not at tolerance for i = 8
# [  0.           1.95098205   4.95872001   9.34211351  15.44949927
#   23.63154017  34.19557184  47.33512572  63.02749756  80.89177471
#  100.        ]
# Iteration 87 : Not at tolerance for i = 1
# Iteration 87 : Not at tolerance for i = 2
# Iteration 87 : Not at tolerance for i = 3
# Iteration 87 : Not at tolerance for i = 4
# Iteration 87 : Not at tolerance for i = 5
# Iteration 87 : Not at tolerance for i = 6
# Iteration 87 : Not at tolerance for i = 7
# Iteration 87 : Not at tolerance for i = 8
# [  0.           1.95212632   4.9614437    9.34680478  15.45640058
#   23.64062084  34.20637913  47.34663004  63.03795715  80.89865602
#  100.        ]
# Iteration 88 : Not at tolerance for i = 1
# Iteration 88 : Not at tolerance for i = 2
# Iteration 88 : Not at tolerance for i = 3
# Iteration 88 : Not at tolerance for i = 4
# Iteration 88 : Not at tolerance for i = 5
# Iteration 88 : Not at tolerance for i = 6
# Iteration 88 : Not at tolerance for i = 7
# Iteration 88 : Not at tolerance for i = 8
# [  0.           1.95320146   4.96400285   9.35121263  15.46288496
#   23.64915292  34.21653352  47.35743935  63.04778484  80.90512161
#  100.        ]
# Iteration 89 : Not at tolerance for i = 1
# Iteration 89 : Not at tolerance for i = 2
# Iteration 89 : Not at tolerance for i = 3
# Iteration 89 : Not at tolerance for i = 4
# Iteration 89 : Not at tolerance for i = 5
# Iteration 89 : Not at tolerance for i = 6
# Iteration 89 : Not at tolerance for i = 7
# Iteration 89 : Not at tolerance for i = 8
# [  0.           1.95421165   4.96640739   9.35535419  15.46897759
#   23.65716954  34.22607444  47.36759562  63.0570188   80.91119658
#  100.        ]
# Iteration 90 : Not at tolerance for i = 1
# Iteration 90 : Not at tolerance for i = 2
# Iteration 90 : Not at tolerance for i = 3
# Iteration 90 : Not at tolerance for i = 4
# Iteration 90 : Not at tolerance for i = 5
# Iteration 90 : Not at tolerance for i = 6
# Iteration 90 : Not at tolerance for i = 7
# Iteration 90 : Not at tolerance for i = 8
# [  0.           1.95516081   4.96866666   9.35924554  15.47470214
#   23.66470185  34.23503896  47.37713832  63.06569491  80.91690455
#  100.        ]
# Iteration 91 : Not at tolerance for i = 1
# Iteration 91 : Not at tolerance for i = 2
# Iteration 91 : Not at tolerance for i = 3
# Iteration 91 : Not at tolerance for i = 4
# Iteration 91 : Not at tolerance for i = 5
# Iteration 91 : Not at tolerance for i = 6
# Iteration 91 : Not at tolerance for i = 7
# Iteration 91 : Not at tolerance for i = 8
# [  0.           1.95605263   4.97078944   9.36290179  15.48008086
#   23.6717791   34.2434619   47.38610451  63.07384686  80.92226767
#  100.        ]
# Iteration 92 : Not at tolerance for i = 1
# Iteration 92 : Not at tolerance for i = 2
# Iteration 92 : Not at tolerance for i = 3
# Iteration 92 : Not at tolerance for i = 4
# Iteration 92 : Not at tolerance for i = 5
# Iteration 92 : Not at tolerance for i = 6
# Iteration 92 : Not at tolerance for i = 7
# Iteration 92 : Not at tolerance for i = 8
# [  0.           1.95689057   4.97278398   9.36633717  15.48513462
#   23.67842879  34.25137598  47.39452901  63.08150633  80.9273068
#  100.        ]
# Iteration 93 : Not at tolerance for i = 1
# Iteration 93 : Not at tolerance for i = 2
# Iteration 93 : Not at tolerance for i = 3
# Iteration 93 : Not at tolerance for i = 4
# Iteration 93 : Not at tolerance for i = 5
# Iteration 93 : Not at tolerance for i = 6
# Iteration 93 : Not at tolerance for i = 7
# Iteration 93 : Not at tolerance for i = 8
# [  0.           1.95767789   4.97465802   9.36956499  15.48988307
#   23.68467675  34.25881195  47.40244457  63.08870306  80.93204148
#  100.        ]
# Iteration 94 : Not at tolerance for i = 1
# Iteration 94 : Not at tolerance for i = 2
# Iteration 94 : Not at tolerance for i = 3
# Iteration 94 : Not at tolerance for i = 4
# Iteration 94 : Not at tolerance for i = 5
# Iteration 94 : Not at tolerance for i = 6
# Iteration 94 : Not at tolerance for i = 7
# Iteration 94 : Not at tolerance for i = 8
# [  0.           1.95841764   4.97641884   9.37259782  15.49434465
#   23.69054725  34.26579868  47.40988192  63.095465    80.93649013
#  100.        ]
# Iteration 95 : Not at tolerance for i = 1
# Iteration 95 : Not at tolerance for i = 2
# Iteration 95 : Not at tolerance for i = 3
# Iteration 95 : Not at tolerance for i = 4
# Iteration 95 : Not at tolerance for i = 5
# Iteration 95 : Not at tolerance for i = 6
# Iteration 95 : Not at tolerance for i = 7
# Iteration 95 : Not at tolerance for i = 8
# [  0.           1.9591127    4.97807328   9.37544742  15.49853669
#   23.69606309  34.27236331  47.41686994  63.10181844  80.94067002
#  100.        ]
# Iteration 96 : Not at tolerance for i = 1
# Iteration 96 : Not at tolerance for i = 2
# Iteration 96 : Not at tolerance for i = 3
# Iteration 96 : Not at tolerance for i = 4
# Iteration 96 : Not at tolerance for i = 5
# Iteration 96 : Not at tolerance for i = 6
# Iteration 96 : Not at tolerance for i = 7
# [  0.           1.95976577   4.97962778   9.37812486  15.50247547
#   23.7012457   34.27853136  47.4234358   63.10778804  80.94459739
#  100.        ]
# Iteration 97 : Not at tolerance for i = 1
# Iteration 97 : Not at tolerance for i = 2
# Iteration 97 : Not at tolerance for i = 3
# Iteration 97 : Not at tolerance for i = 4
# Iteration 97 : Not at tolerance for i = 5
# Iteration 97 : Not at tolerance for i = 6
# Iteration 97 : Not at tolerance for i = 7
# [  0.           1.96037939   4.98108836   9.38064055  15.5061763
#   23.7061152   34.28432677  47.42960499  63.11339699  80.9482875
#  100.        ]
# Iteration 98 : Not at tolerance for i = 1
# Iteration 98 : Not at tolerance for i = 2
# Iteration 98 : Not at tolerance for i = 3
# Iteration 98 : Not at tolerance for i = 4
# Iteration 98 : Not at tolerance for i = 5
# Iteration 98 : Not at tolerance for i = 6
# Iteration 98 : Not at tolerance for i = 7
# [  0.           1.96095593   4.9824607    9.38300426  15.50965354
#   23.71069053  34.28977205  47.43540148  63.11866709  80.95175466
#  100.        ]
# Iteration 99 : Not at tolerance for i = 1
# Iteration 99 : Not at tolerance for i = 2
# Iteration 99 : Not at tolerance for i = 3
# Iteration 99 : Not at tolerance for i = 4
# Iteration 99 : Not at tolerance for i = 5
# Iteration 99 : Not at tolerance for i = 6
# Iteration 99 : Not at tolerance for i = 7
# [  0.           1.96149764   4.98375013   9.38522517  15.51292071
#   23.71498944  34.29488837  47.44084778  63.1236188   80.95501237
#  100.        ]
# Iteration 100 : Not at tolerance for i = 1
# Iteration 100 : Not at tolerance for i = 2
# Iteration 100 : Not at tolerance for i = 3
# Iteration 100 : Not at tolerance for i = 4
# Iteration 100 : Not at tolerance for i = 5
# Iteration 100 : Not at tolerance for i = 6
# Iteration 100 : Not at tolerance for i = 7
# [  0.           1.96200663   4.98496167   9.3873119   15.5159905
#   23.71902864  34.2996956   47.44596505  63.12827136  80.95807327
#  100.        ]
# Iteration 101 : Not at tolerance for i = 1
# Iteration 101 : Not at tolerance for i = 2
# Iteration 101 : Not at tolerance for i = 3
# Iteration 101 : Not at tolerance for i = 4
# Iteration 101 : Not at tolerance for i = 5
# Iteration 101 : Not at tolerance for i = 6
# Iteration 101 : Not at tolerance for i = 7
# [  0.           1.96248487   4.98610001   9.38927257  15.51887484
#   23.72282381  34.3042124   47.45077317  63.13264285  80.96094924
#  100.        ]
# Iteration 102 : Not at tolerance for i = 1
# Iteration 102 : Not at tolerance for i = 2
# Iteration 102 : Not at tolerance for i = 3
# Iteration 102 : Not at tolerance for i = 4
# Iteration 102 : Not at tolerance for i = 5
# Iteration 102 : Not at tolerance for i = 6
# [  0.           1.96293421   4.98716958   9.39111479  15.52158492
#   23.72638971  34.30845632  47.45529081  63.13675023  80.96365147
#  100.        ]
# Iteration 103 : Not at tolerance for i = 1
# Iteration 103 : Not at tolerance for i = 2
# Iteration 103 : Not at tolerance for i = 3
# Iteration 103 : Not at tolerance for i = 4
# Iteration 103 : Not at tolerance for i = 5
# Iteration 103 : Not at tolerance for i = 6
# [  0.           1.96335641   4.98817453   9.39284571  15.52413127
#   23.72974018  34.31244386  47.45953552  63.14060948  80.96619045
#  100.        ]
# Iteration 104 : Not at tolerance for i = 1
# Iteration 104 : Not at tolerance for i = 2
# Iteration 104 : Not at tolerance for i = 3
# Iteration 104 : Not at tolerance for i = 4
# Iteration 104 : Not at tolerance for i = 5
# Iteration 104 : Not at tolerance for i = 6
# [  0.           1.9637531    4.98911877   9.39447206  15.52652379
#   23.73288823  34.31619049  47.4635238   63.14423557  80.96857603
#  100.        ]
# Iteration 105 : Not at tolerance for i = 1
# Iteration 105 : Not at tolerance for i = 2
# Iteration 105 : Not at tolerance for i = 3
# Iteration 105 : Not at tolerance for i = 4
# Iteration 105 : Not at tolerance for i = 5
# Iteration 105 : Not at tolerance for i = 6
# [  0.           1.96412583   4.99000597   9.39600016  15.52877177
#   23.7358461   34.31971077  47.46727113  63.1476426   80.9708175
#  100.        ]
# Iteration 106 : Not at tolerance for i = 1
# Iteration 106 : Not at tolerance for i = 2
# Iteration 106 : Not at tolerance for i = 3
# Iteration 106 : Not at tolerance for i = 4
# Iteration 106 : Not at tolerance for i = 5
# [  0.           1.96447604   4.99083956   9.39743594  15.53088395
#   23.73862527  34.32301839  47.47079207  63.15084379  80.97292355
#  100.        ]
# Iteration 107 : Not at tolerance for i = 1
# Iteration 107 : Not at tolerance for i = 2
# Iteration 107 : Not at tolerance for i = 3
# Iteration 107 : Not at tolerance for i = 4
# Iteration 107 : Not at tolerance for i = 5
# [  0.           1.96480509   4.9916228    9.39878498  15.53286851
#   23.74123654  34.32612617  47.4741003   63.1538516   80.97490237
#  100.        ]
# Iteration 108 : Not at tolerance for i = 1
# Iteration 108 : Not at tolerance for i = 2
# Iteration 108 : Not at tolerance for i = 3
# Iteration 108 : Not at tolerance for i = 4
# Iteration 108 : Not at tolerance for i = 5
# [  0.           1.96511426   4.99235872   9.40005252  15.53473318
#   23.74369006  34.32904621  47.47720866  63.15667768  80.97676163
#  100.        ]
# Iteration 109 : Not at tolerance for i = 1
# Iteration 109 : Not at tolerance for i = 2
# Iteration 109 : Not at tolerance for i = 3
# Iteration 109 : Not at tolerance for i = 4
# [  0.           1.96540476   4.99305017   9.40124348  15.53648521
#   23.74599535  34.33178983  47.48012924  63.15933304  80.97850858
#  100.        ]
# Iteration 110 : Not at tolerance for i = 1
# Iteration 110 : Not at tolerance for i = 2
# Iteration 110 : Not at tolerance for i = 3
# Iteration 110 : Not at tolerance for i = 4
# [  0.           1.9656777    4.99369986   9.40236249  15.53813138
#   23.74816137  34.33436771  47.48287337  63.16182797  80.98014998
#  100.        ]
# Iteration 111 : Not at tolerance for i = 1
# Iteration 111 : Not at tolerance for i = 2
# Iteration 111 : Not at tolerance for i = 3
# [  0.           1.96593416   4.9943103    9.4034139   15.5396781
#   23.75019653  34.33678984  47.48545173  63.16417218  80.98169222
#  100.        ]
# Iteration 112 : Not at tolerance for i = 1
# Iteration 112 : Not at tolerance for i = 2
# Iteration 112 : Not at tolerance for i = 3
# [  0.           1.96617512   4.99488385   9.40440179  15.54113138
#   23.75210874  34.33906564  47.48787431  63.16637477  80.98314129
#  100.        ]
# Iteration 113 : Not at tolerance for i = 1
# Iteration 113 : Not at tolerance for i = 2
# [  0.           1.96640152   4.99542276   9.40532999  15.54249687
#   23.75390543  34.34120396  47.49015054  63.16844429  80.98450282
#  100.        ]
# Iteration 114 : Not at tolerance for i = 1
# Iteration 114 : Not at tolerance for i = 2
# [  0.           1.96661425   4.99592911   9.40620212  15.54377986
#   23.75559357  34.34321309  47.49228925  63.17038878  80.98578209
#  100.        ]
# Iteration 115 : Not at tolerance for i = 1
# [  0.           1.96681412   4.99640486   9.40702156  15.54498533
#   23.75717973  34.34510084  47.49429876  63.1722158   80.98698408
#  100.        ]
# [  0.           1.96700192   4.99685188   9.4077915   15.54611799
#   23.75867006  34.34687455  47.49618686  63.17393244  80.98811345
#  100.        ]

# %% [markdown]
# ## Successive Over-Relaxation (SOR)
#
# We hope that each iteration will bring us closer to the stable correct solution for the discrete grid.
# The system is **relaxing** to its stable state.
# The rate of relaxation to the stable value depends on the coefficients of the differential equation itself.
#
# We can push the relaxation to happen faster by replacing the $y_i$ values from the iteration with our own guesses.
# The key is to exaggerate the difference with respect to the previous iteration, in hopes of reaching a stable point faster.
# Instead of just taking
#
# $$y_i^{(j)} = \frac{1}{2- 10h^2} \left[ \left( 1- \frac{5h}{2} \right) y_{i+1}^{(j-1)} + \left( 1+ \frac{5h}{2} \right) y_{i-1}^{(j)} - 10h^2 x_i \right]$$
#
# we substitute in our own adjusted guess $\bar{y}_i^{(j)}$:
#
# $$\bar{y}_i^{(j)} = y_i^{(j)} + \alpha \left[ y_i^{(j)} - y_i^{(j-1)} \right]$$
#
# This is called **over-relaxation** because it pushes us further away from $y_i^{(j-1)}$ than we would have otherwise.  Useful values of $\alpha$ are between 0 and 1 (but be careful with different definitions of $\alpha$).
# Of course, if $\alpha=0$, we recover our usual method.
# If $\alpha=1$, we are doubling our iterative change in $y_i$, which is aggressive.
# As the change in $y_i$ goes to zero, the correction from SOR also goes smoothly to zero.

# %%
# Implement SOR with Jacobi method

# Jacobi method

N = 11
(x_grid_points, h) = np.linspace(0., 1., 11, retstep=True)
c1 = 1.0 - 2.5*h
c2 = 1.0 + 2.5*h
c3 = -10.0 * pow(h,2)
c4 = 2.0 + c3

old_y_values = np.zeros(N)
old_y_values[0] = 0.
old_y_values[N-1] = 100.
y_values = old_y_values.copy()

alpha = 0.5
tolerance = 0.0001
achieved_tolerance = False
iteration = 0
while (not achieved_tolerance):
    iteration += 1
    achieved_tolerance = True   # until we know otherwise
    for i in range(1,N-1):
        yy = 1./c4 * (c1*old_y_values[i+1] + c2*y_values[i-1] + c3*x_grid_points[i])
        if (abs((yy-old_y_values[i]))/yy > tolerance):
            achieved_tolerance = False
            print('Iteration', iteration, ': Not at tolerance for i =', i)
        y_values[i] = yy + alpha*(yy-old_y_values[i])
        old_y_values[i] = y_values[i]
        
    print(y_values)
# Out:
# Iteration 1 : Not at tolerance for i = 9
# [ 0.00000000e+00 -7.89473684e-03 -2.35803324e-02 -4.69542754e-02
#  -7.79154034e-02 -1.16363885e-01 -1.62201202e-01 -2.15330134e-01
#  -2.75654737e-01  5.88674460e+01  1.00000000e+02]
# Iteration 2 : Not at tolerance for i = 8
# Iteration 2 : Not at tolerance for i = 9
# [ 0.00000000e+00 -1.79094073e-02 -4.94749383e-02 -9.51651455e-02
#  -1.55433887e-01 -2.30720631e-01 -3.21450759e-01 -4.28035856e-01
#   3.45079903e+01  6.37596885e+01  1.00000000e+02]
# Iteration 3 : Not at tolerance for i = 7
# Iteration 3 : Not at tolerance for i = 8
# Iteration 3 : Not at tolerance for i = 9
# [ 0.00000000e+00 -2.82344045e-02 -7.52626873e-02 -1.42407249e-01
#  -2.31006374e-01 -3.42412871e-01 -4.77992763e-01  2.01194140e+01
#   4.02899790e+01  6.70194771e+01  1.00000000e+02]
# Iteration 4 : Not at tolerance for i = 6
# Iteration 4 : Not at tolerance for i = 7
# Iteration 4 : Not at tolerance for i = 8
# Iteration 4 : Not at tolerance for i = 9
# [ 0.00000000e+00 -3.83409678e-02 -1.00314693e-01 -1.88255439e-01
#  -3.04598617e-01 -4.51880020e-01  1.16585047e+01  2.52460417e+01
#   4.43882947e+01  6.94339733e+01  1.00000000e+02]
# Iteration 5 : Not at tolerance for i = 5
# Iteration 5 : Not at tolerance for i = 6
# Iteration 5 : Not at tolerance for i = 7
# Iteration 5 : Not at tolerance for i = 8
# Iteration 5 : Not at tolerance for i = 9
# [ 0.00000000e+00 -4.81211107e-02 -1.24587101e-01 -2.32858733e-01
#  -3.76634979e-01  6.71784905e+00  1.57011497e+01  2.90988146e+01
#   4.75708512e+01  7.13674060e+01  1.00000000e+02]
# Iteration 6 : Not at tolerance for i = 4
# Iteration 6 : Not at tolerance for i = 5
# Iteration 6 : Not at tolerance for i = 6
# Iteration 6 : Not at tolerance for i = 7
# Iteration 6 : Not at tolerance for i = 8
# Iteration 6 : Not at tolerance for i = 9
# [ 0.00000000e+00 -5.76028599e-02 -1.48217732e-01 -2.76529896e-01
#   3.86152098e+00  9.70904667e+00  1.89129140e+01  3.22263408e+01
#   5.02107432e+01  7.30058462e+01  1.00000000e+02]
# Iteration 7 : Not at tolerance for i = 3
# Iteration 7 : Not at tolerance for i = 4
# Iteration 7 : Not at tolerance for i = 5
# Iteration 7 : Not at tolerance for i = 6
# Iteration 7 : Not at tolerance for i = 7
# Iteration 7 : Not at tolerance for i = 8
# Iteration 7 : Not at tolerance for i = 9
# [ 0.00000000e+00 -6.68538060e-02 -1.71389565e-01  2.23187319e+00
#   5.98894464e+00  1.22145817e+01  2.16314241e+01  3.49084118e+01
#   5.25077069e+01  7.44533666e+01  1.00000000e+02]
# Iteration 8 : Not at tolerance for i = 2
# Iteration 8 : Not at tolerance for i = 3
# Iteration 8 : Not at tolerance for i = 4
# Iteration 8 : Not at tolerance for i = 5
# Iteration 8 : Not at tolerance for i = 6
# Iteration 8 : Not at tolerance for i = 7
# Iteration 8 : Not at tolerance for i = 8
# Iteration 8 : Not at tolerance for i = 9
# [ 0.00000000e+00 -7.59484975e-02  1.31646000e+00  3.70560299e+00
#   7.86311187e+00  1.44209654e+01  2.40375898e+01  3.73019262e+01
#   5.45783303e+01  7.57729848e+01  1.00000000e+02]
# Iteration 9 : Not at tolerance for i = 1
# Iteration 9 : Not at tolerance for i = 2
# Iteration 9 : Not at tolerance for i = 3
# Iteration 9 : Not at tolerance for i = 4
# Iteration 9 : Not at tolerance for i = 5
# Iteration 9 : Not at tolerance for i = 6
# Iteration 9 : Not at tolerance for i = 7
# Iteration 9 : Not at tolerance for i = 8
# Iteration 9 : Not at tolerance for i = 9
# [  0.           0.80956241   2.31899783   5.06778892   9.57670211
#   16.43351991  26.23779293  39.50244915  56.49594013  77.0055538
#  100.        ]
# Iteration 10 : Not at tolerance for i = 1
# Iteration 10 : Not at tolerance for i = 2
# Iteration 10 : Not at tolerance for i = 3
# Iteration 10 : Not at tolerance for i = 4
# Iteration 10 : Not at tolerance for i = 5
# Iteration 10 : Not at tolerance for i = 6
# Iteration 10 : Not at tolerance for i = 7
# Iteration 10 : Not at tolerance for i = 8
# Iteration 10 : Not at tolerance for i = 9
# [  0.           0.96041488   2.77315395   5.84950213  10.68297863
#   17.82171477  27.81056168  41.089689    57.83330094  77.70903324
#  100.        ]
# Iteration 11 : Not at tolerance for i = 1
# Iteration 11 : Not at tolerance for i = 2
# Iteration 11 : Not at tolerance for i = 3
# Iteration 11 : Not at tolerance for i = 4
# Iteration 11 : Not at tolerance for i = 5
# Iteration 11 : Not at tolerance for i = 6
# Iteration 11 : Not at tolerance for i = 7
# Iteration 11 : Not at tolerance for i = 8
# Iteration 11 : Not at tolerance for i = 9
# [  0.           1.15389687   3.19986857   6.53477763  11.62805656
#   18.9915047   29.11838833  42.37854586  58.85305262  78.36362742
#  100.        ]
# Iteration 12 : Not at tolerance for i = 1
# Iteration 12 : Not at tolerance for i = 2
# Iteration 12 : Not at tolerance for i = 3
# Iteration 12 : Not at tolerance for i = 4
# Iteration 12 : Not at tolerance for i = 5
# Iteration 12 : Not at tolerance for i = 6
# Iteration 12 : Not at tolerance for i = 7
# Iteration 12 : Not at tolerance for i = 8
# Iteration 12 : Not at tolerance for i = 9
# [  0.           1.30981585   3.5461339    7.09343471  12.3994627
#   19.94223683  30.16583644  43.37158366  59.71073696  78.88272934
#  100.        ]
# Iteration 13 : Not at tolerance for i = 1
# Iteration 13 : Not at tolerance for i = 2
# Iteration 13 : Not at tolerance for i = 3
# Iteration 13 : Not at tolerance for i = 4
# Iteration 13 : Not at tolerance for i = 5
# Iteration 13 : Not at tolerance for i = 6
# Iteration 13 : Not at tolerance for i = 7
# Iteration 13 : Not at tolerance for i = 8
# Iteration 13 : Not at tolerance for i = 9
# [  0.           1.43688188   3.82917915   7.55018077  13.02742937
#   20.70677425  30.98457301  44.19086789  60.39776195  79.30116357
#  100.        ]
# Iteration 14 : Not at tolerance for i = 1
# Iteration 14 : Not at tolerance for i = 2
# Iteration 14 : Not at tolerance for i = 3
# Iteration 14 : Not at tolerance for i = 4
# Iteration 14 : Not at tolerance for i = 5
# Iteration 14 : Not at tolerance for i = 6
# Iteration 14 : Not at tolerance for i = 7
# Iteration 14 : Not at tolerance for i = 8
# Iteration 14 : Not at tolerance for i = 9
# [  0.           1.54094145   4.06078863   7.9221921   13.53324911
#   21.30844799  31.65406421  44.848699    60.95118199  79.63808465
#  100.        ]
# Iteration 15 : Not at tolerance for i = 1
# Iteration 15 : Not at tolerance for i = 2
# Iteration 15 : Not at tolerance for i = 3
# Iteration 15 : Not at tolerance for i = 4
# Iteration 15 : Not at tolerance for i = 5
# Iteration 15 : Not at tolerance for i = 6
# Iteration 15 : Not at tolerance for i = 7
# Iteration 15 : Not at tolerance for i = 8
# Iteration 15 : Not at tolerance for i = 9
# [  0.           1.62604886   4.24924133   8.22165803  13.93211902
#   21.797642    32.19158112  45.37791068  61.39621309  79.90879954
#  100.        ]
# Iteration 16 : Not at tolerance for i = 1
# Iteration 16 : Not at tolerance for i = 2
# Iteration 16 : Not at tolerance for i = 3
# Iteration 16 : Not at tolerance for i = 4
# Iteration 16 : Not at tolerance for i = 5
# Iteration 16 : Not at tolerance for i = 6
# Iteration 16 : Not at tolerance for i = 7
# Iteration 16 : Not at tolerance for i = 8
# Iteration 16 : Not at tolerance for i = 9
# [  0.           1.69507899   4.40045217   8.45731926  14.25489884
#   22.1898443   32.62321343  45.80276303  61.75325144  80.12578257
#  100.        ]
# Iteration 17 : Not at tolerance for i = 1
# Iteration 17 : Not at tolerance for i = 2
# Iteration 17 : Not at tolerance for i = 3
# Iteration 17 : Not at tolerance for i = 4
# Iteration 17 : Not at tolerance for i = 5
# Iteration 17 : Not at tolerance for i = 6
# Iteration 17 : Not at tolerance for i = 7
# Iteration 17 : Not at tolerance for i = 8
# Iteration 17 : Not at tolerance for i = 9
# [  0.           1.75009666   4.51867676   8.64727727  14.51319254
#   22.50421002  32.96918392  46.14315938  62.03912651  80.29940461
#  100.        ]
# Iteration 18 : Not at tolerance for i = 1
# Iteration 18 : Not at tolerance for i = 2
# Iteration 18 : Not at tolerance for i = 3
# Iteration 18 : Not at tolerance for i = 4
# Iteration 18 : Not at tolerance for i = 5
# Iteration 18 : Not at tolerance for i = 6
# Iteration 18 : Not at tolerance for i = 7
# Iteration 18 : Not at tolerance for i = 8
# Iteration 18 : Not at tolerance for i = 9
# [  0.           1.79258922   4.61397306   8.79927773  14.72018374
#   22.75614573  33.24636991  46.41576816  62.26801331  80.43846873
#  100.        ]
# Iteration 19 : Not at tolerance for i = 1
# Iteration 19 : Not at tolerance for i = 2
# Iteration 19 : Not at tolerance for i = 3
# Iteration 19 : Not at tolerance for i = 4
# Iteration 19 : Not at tolerance for i = 5
# Iteration 19 : Not at tolerance for i = 6
# Iteration 19 : Not at tolerance for i = 7
# Iteration 19 : Not at tolerance for i = 8
# Iteration 19 : Not at tolerance for i = 9
# [  0.           1.82776838   4.69104145   8.92189241  14.88686193
#   22.95878623  33.46916417  46.63485161  62.45211128  80.5506123
#  100.        ]
# Iteration 20 : Not at tolerance for i = 1
# Iteration 20 : Not at tolerance for i = 2
# Iteration 20 : Not at tolerance for i = 3
# Iteration 20 : Not at tolerance for i = 4
# Iteration 20 : Not at tolerance for i = 5
# Iteration 20 : Not at tolerance for i = 6
# Iteration 20 : Not at tolerance for i = 7
# Iteration 20 : Not at tolerance for i = 8
# Iteration 20 : Not at tolerance for i = 9
# [  0.           1.8558114    4.75278209   9.02020437  15.02052571
#   23.12128868  33.64785178  46.81065171  62.59995004  80.64043402
#  100.        ]
# Iteration 21 : Not at tolerance for i = 1
# Iteration 21 : Not at tolerance for i = 2
# Iteration 21 : Not at tolerance for i = 3
# Iteration 21 : Not at tolerance for i = 4
# Iteration 21 : Not at tolerance for i = 5
# Iteration 21 : Not at tolerance for i = 6
# Iteration 21 : Not at tolerance for i = 7
# Iteration 21 : Not at tolerance for i = 8
# Iteration 21 : Not at tolerance for i = 9
# [  0.           1.87834685   4.80236172   9.09911869  15.12778836
#   23.25169062  33.79128626  46.95183495  62.71854014  80.71255287
#  100.        ]
# Iteration 22 : Not at tolerance for i = 1
# Iteration 22 : Not at tolerance for i = 2
# Iteration 22 : Not at tolerance for i = 3
# Iteration 22 : Not at tolerance for i = 4
# Iteration 22 : Not at tolerance for i = 5
# Iteration 22 : Not at tolerance for i = 6
# Iteration 22 : Not at tolerance for i = 7
# Iteration 22 : Not at tolerance for i = 8
# Iteration 22 : Not at tolerance for i = 9
# [  0.           1.89643549   4.84214812   9.1624352   15.21385211
#   23.35634929  33.90644594  47.06510558  62.81372726  80.7704281
#  100.        ]
# Iteration 23 : Not at tolerance for i = 1
# Iteration 23 : Not at tolerance for i = 2
# Iteration 23 : Not at tolerance for i = 3
# Iteration 23 : Not at tolerance for i = 4
# Iteration 23 : Not at tolerance for i = 5
# Iteration 23 : Not at tolerance for i = 6
# Iteration 23 : Not at tolerance for i = 7
# Iteration 23 : Not at tolerance for i = 8
# Iteration 23 : Not at tolerance for i = 9
# [  0.           1.91094891   4.87406741   9.21323504  15.28292061
#   23.44036631  33.99884577  47.1560151   62.89011528  80.8168734
#  100.        ]
# Iteration 24 : Not at tolerance for i = 1
# Iteration 24 : Not at tolerance for i = 2
# Iteration 24 : Not at tolerance for i = 3
# Iteration 24 : Not at tolerance for i = 4
# Iteration 24 : Not at tolerance for i = 5
# Iteration 24 : Not at tolerance for i = 6
# Iteration 24 : Not at tolerance for i = 7
# Iteration 24 : Not at tolerance for i = 8
# Iteration 24 : Not at tolerance for i = 9
# [  0.           1.92259178   4.8996763    9.25400287  15.33836469
#   23.50778278  34.07300327  47.22897183  62.95141855  80.85414739
#  100.        ]
# Iteration 25 : Not at tolerance for i = 1
# Iteration 25 : Not at tolerance for i = 2
# Iteration 25 : Not at tolerance for i = 3
# Iteration 25 : Not at tolerance for i = 4
# Iteration 25 : Not at tolerance for i = 5
# Iteration 25 : Not at tolerance for i = 6
# Iteration 25 : Not at tolerance for i = 7
# Iteration 25 : Not at tolerance for i = 8
# Iteration 25 : Not at tolerance for i = 9
# [  0.           1.9319335    4.9202295    9.28673045  15.38285725
#   23.56189073  34.13251859  47.28752367  63.00061847  80.88406295
#  100.        ]
# Iteration 26 : Not at tolerance for i = 1
# Iteration 26 : Not at tolerance for i = 2
# Iteration 26 : Not at tolerance for i = 3
# Iteration 26 : Not at tolerance for i = 4
# Iteration 26 : Not at tolerance for i = 5
# Iteration 26 : Not at tolerance for i = 6
# Iteration 26 : Not at tolerance for i = 7
# Iteration 26 : Not at tolerance for i = 8
# Iteration 26 : Not at tolerance for i = 9
# [  0.           1.9394323    4.93673121   9.31299552  15.41856804
#   23.605317    34.18028466  47.33451685  63.04010651  80.90807364
#  100.        ]
# Iteration 27 : Not at tolerance for i = 1
# Iteration 27 : Not at tolerance for i = 2
# Iteration 27 : Not at tolerance for i = 3
# Iteration 27 : Not at tolerance for i = 4
# Iteration 27 : Not at tolerance for i = 5
# Iteration 27 : Not at tolerance for i = 6
# Iteration 27 : Not at tolerance for i = 7
# Iteration 27 : Not at tolerance for i = 8
# Iteration 27 : Not at tolerance for i = 9
# [  0.           1.94545364   4.94997416   9.33407624  15.44722891
#   23.64017016  34.21862109  47.37223335  63.07179957  80.92734434
#  100.        ]
# Iteration 28 : Not at tolerance for i = 1
# Iteration 28 : Not at tolerance for i = 2
# Iteration 28 : Not at tolerance for i = 3
# Iteration 28 : Not at tolerance for i = 4
# Iteration 28 : Not at tolerance for i = 5
# Iteration 28 : Not at tolerance for i = 6
# Iteration 28 : Not at tolerance for i = 7
# Iteration 28 : Not at tolerance for i = 8
# Iteration 28 : Not at tolerance for i = 9
# [  0.           1.95028419   4.96060167   9.35099381  15.47023018
#   23.66814141  34.24938822  47.40250303  63.09723472  80.94280946
#  100.        ]
# Iteration 29 : Not at tolerance for i = 1
# Iteration 29 : Not at tolerance for i = 2
# Iteration 29 : Not at tolerance for i = 3
# Iteration 29 : Not at tolerance for i = 4
# Iteration 29 : Not at tolerance for i = 5
# Iteration 29 : Not at tolerance for i = 6
# Iteration 29 : Not at tolerance for i = 7
# Iteration 29 : Not at tolerance for i = 8
# Iteration 29 : Not at tolerance for i = 9
# [  0.           1.95416153   4.96913121   9.36457151  15.48869052
#   23.6905906   34.2740813   47.42679664  63.11764808  80.95522167
#  100.        ]
# Iteration 30 : Not at tolerance for i = 1
# Iteration 30 : Not at tolerance for i = 2
# Iteration 30 : Not at tolerance for i = 3
# Iteration 30 : Not at tolerance for i = 4
# Iteration 30 : Not at tolerance for i = 5
# Iteration 30 : Not at tolerance for i = 6
# Iteration 30 : Not at tolerance for i = 7
# Iteration 30 : Not at tolerance for i = 8
# [  0.           1.95727325   4.97597665   9.37546848  15.50350623
#   23.70860767  34.29389914  47.44629377  63.13403133  80.96518324
#  100.        ]
# Iteration 31 : Not at tolerance for i = 1
# Iteration 31 : Not at tolerance for i = 2
# Iteration 31 : Not at tolerance for i = 3
# Iteration 31 : Not at tolerance for i = 4
# Iteration 31 : Not at tolerance for i = 5
# Iteration 31 : Not at tolerance for i = 6
# Iteration 31 : Not at tolerance for i = 7
# Iteration 31 : Not at tolerance for i = 8
# [  0.           1.9597706    4.98147058   9.3842141   15.51539692
#   23.72306762  34.30980426  47.46194166  63.14717999  80.97317811
#  100.        ]
# Iteration 32 : Not at tolerance for i = 1
# Iteration 32 : Not at tolerance for i = 2
# Iteration 32 : Not at tolerance for i = 3
# Iteration 32 : Not at tolerance for i = 4
# Iteration 32 : Not at tolerance for i = 5
# Iteration 32 : Not at tolerance for i = 6
# Iteration 32 : Not at tolerance for i = 7
# Iteration 32 : Not at tolerance for i = 8
# [  0.           1.96177491   4.98587988   9.39123311  15.52494004
#   23.7346727   34.32256928  47.47450017  63.15773274  80.97959457
#  100.        ]
# Iteration 33 : Not at tolerance for i = 1
# Iteration 33 : Not at tolerance for i = 2
# Iteration 33 : Not at tolerance for i = 3
# Iteration 33 : Not at tolerance for i = 4
# Iteration 33 : Not at tolerance for i = 5
# Iteration 33 : Not at tolerance for i = 6
# Iteration 33 : Not at tolerance for i = 7
# [  0.           1.96338352   4.98941867   9.39686637  15.53259905
#   23.74398663  34.3328141   47.48457927  63.16620206  80.98474422
#  100.        ]
# Iteration 34 : Not at tolerance for i = 1
# Iteration 34 : Not at tolerance for i = 2
# Iteration 34 : Not at tolerance for i = 3
# Iteration 34 : Not at tolerance for i = 4
# Iteration 34 : Not at tolerance for i = 5
# Iteration 34 : Not at tolerance for i = 6
# Iteration 34 : Not at tolerance for i = 7
# [  0.           1.96467456   4.9922588    9.40138744  15.53874595
#   23.7514617   34.34103629  47.49266846  63.17299929  80.98887719
#  100.        ]
# Iteration 35 : Not at tolerance for i = 1
# Iteration 35 : Not at tolerance for i = 2
# Iteration 35 : Not at tolerance for i = 3
# Iteration 35 : Not at tolerance for i = 4
# Iteration 35 : Not at tolerance for i = 5
# Iteration 35 : Not at tolerance for i = 6
# [  0.           1.9657107    4.99453819   9.40501591  15.54367926
#   23.75746096  34.34763518  47.49916059  63.17845454  80.99219417
#  100.        ]
# Iteration 36 : Not at tolerance for i = 1
# Iteration 36 : Not at tolerance for i = 2
# Iteration 36 : Not at tolerance for i = 3
# Iteration 36 : Not at tolerance for i = 4
# Iteration 36 : Not at tolerance for i = 5
# Iteration 36 : Not at tolerance for i = 6
# [  0.           1.96654226   4.99636756   9.40792801  15.54763859
#   23.7622758   34.35293124  47.50437099  63.18283276  80.99485629
#  100.        ]
# Iteration 37 : Not at tolerance for i = 1
# Iteration 37 : Not at tolerance for i = 2
# Iteration 37 : Not at tolerance for i = 3
# Iteration 37 : Not at tolerance for i = 4
# Iteration 37 : Not at tolerance for i = 5
# [  0.           1.96720966   4.99783576   9.41026518  15.55081623
#   23.76614004  34.35718171  47.50855269  63.18634658  80.99699283
#  100.        ]
# Iteration 38 : Not at tolerance for i = 1
# Iteration 38 : Not at tolerance for i = 2
# Iteration 38 : Not at tolerance for i = 3
# Iteration 38 : Not at tolerance for i = 4
# [  0.           1.96774529   4.99901409   9.41214093  15.55336651
#   23.76924136  34.360593    47.51190881  63.18916668  80.99870754
#  100.        ]
# Iteration 39 : Not at tolerance for i = 1
# Iteration 39 : Not at tolerance for i = 2
# Iteration 39 : Not at tolerance for i = 3
# [  0.           1.96817517   4.99995979   9.41364634  15.55541328
#   23.77173039  34.36333081  47.51460232  63.19143     81.00008373
#  100.        ]
# Iteration 40 : Not at tolerance for i = 1
# Iteration 40 : Not at tolerance for i = 2
# [  0.           1.96852018   5.00071878   9.41485454  15.55705597
#   23.77372801  34.36552809  47.51676406  63.19324647  81.00118821
#  100.        ]
# [  0.           1.96879708   5.00132792   9.41582421  15.55837433
#   23.77533124  34.36729156  47.518499    63.19470432  81.00207463
#  100.        ]

# %% [markdown]
# Try some different values of $\alpha$ and notice how the required number of iterations changes.
# Make sure you try $\alpha=0,0.5,1.0$ for comparisons.

# %% [markdown]
# ## Linear Algebra Form
#
# You may have noticed that the equation
#
# $$\frac{d^2 y}{dx^2} = 5 \frac{dy}{dx} - 10 y(x) + 10x$$
#
# gives formulae for $y_i$ with recognizable coefficients:
#
# $$y_i = \frac{1}{2- 10h^2} \left[ \left( 1- \frac{5h}{2} \right) y_{i+1} + \left( 1+ \frac{5h}{2} \right) y_{i-1} - 10h^2 x_i \right]$$
#
# There are $N-2$ equations for the $N-2$ unknown $y_i$, so the system of equations will be a square matrix of order $N-2$.
# To make things cleaner, let's write some generic coefficients.
#
# Assume some generic coefficients $(u,v,w)$:
# $$\begin{align}
# f(x,y,y') &= u(x) + v(x) y + w(x) y' \\
# y_0 &= \alpha \\
# y_N &= \beta
# \end{align}$$
#
# The difference equation looks like
#
# $$\frac{1}{h^2} \left( y_{i-1} - 2 y_i + y_{i+1} \right) = u(x_i) + v(x_i) y_i  + w(x_i) \left[ \frac{1}{2h} \left( x_{i+1} - x_{i-1} \right) \right]$$
#
# After gathering terms by $y_i$, we have a more organized difference equation
#
# $$-\left( 1 + \frac{h}{2} w_i \right) y_{i-1} + (2+h^2 v_i) y_i + \left( 1 - \frac{h}{2} w_i \right) y_{i+1} = -h^2 u_i$$
#
# Now you can see the recognizable coefficients again.
#
# $$\begin{cases}
# a_i &=  -\left( 1 + \frac{h}{2} w_i \right) \\
# d_i &= 2 + h^2 v_i \\
# c_i &= - \left( 1 - \frac{h}{2} w_i \right) \\
# b_i &= -h^2 u_i
# \end{cases}$$
#
# With these coefficients, the main difference equation (the "more organized" one) assumes an obviously linear form:
#
# $$a_i y_{i-1} + d_i y_i + c_i y_{i+1} = b_i$$
#
# The $i=1$ and $i=N-1$ equations are special, because they are next to the boundaries, with boundary condition values $\alpha$ and $\beta$:
#
# $$\begin{cases}
#  & & d_1 y_1 & + & c_1 y_2 &=  b_1 - a_1 \alpha \\
# a_i y_{i-1} & + & d_i y_i & + & c_i y_{i+1} &= b_i \\
# a_{N-1} y_{N-2} & + & d_{N-1} y_{N-1} & & &= b_{N-1} - c_{N-1} \beta
# \end{cases}$$
#
# We don't even write the $i=0$ and $i=N$ equations; they are the boundary conditions!
#
# Now we can finally write this system in matrix form.  From here we can use any sort of linear algebra solver to find the $y_i$ values.
#
# $$\begin{bmatrix}
# d_1 & c_1 & & & & \\
# a_2 & d_2 & c_2 & & & \\
#  & a_3 & d_3 & c_3 & & \\
#  & & \ddots & \ddots & \ddots & \\
#  & & & a_{n-2} & d_{n-2} & c_{n-2} \\
#  & & & & a_{n-1} & d_{n-1} \\
# \end{bmatrix}
# \begin{bmatrix}
# y_1 \\
# y_2 \\
# y_3 \\
# \dots \\
# y_{n-2} \\
# y_{n-1}
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1 & - a_1 \alpha \\
# b_2 & \\
# b_3 & \\
# \vdots \\
# b_{n-2} & \\
# b_{n-1} & - c_{n-1} \beta
# \end{bmatrix}
# $$
#
# This is a tridiagonal matrix, and it can be solved with Gaussian elimination methods.
#
# Note that this is **not an iterative method**!
# It gives the exact solution to the system of equations.
# (Of course, these difference equations are themselves approximations to the differential equation.)

# %% [markdown]
# # Finite Element Method
#
# The other discretization method is the **finite element** method.
# In this method, we adopt a trial function that it supposed to approximate the exact solution, and we solve constraint equations for the parameters of the trial function.
# (You might think of this as being similar to the variational method, in the sense of a trial solution.)
#
# The constraint equations are designed to minimize the total residual error between the exact derivative $y''$ and the second derivative of the trial function.
# By total residual error, we mean the **integrated** residual error (probably the residual error squared) over all of the discrete intervals.
#
# Let's look at a simple example:
#
# $$\begin{align}
# y'' - 6x &= 0 \\
# y(0) &= 0\\
# y(1) &= 1
# \end{align}$$
#
# A guess for the trial function might look like
#
# $$p(x) = \alpha x^2 + \beta x + \gamma$$
#
# The boundary conditions require $\gamma=0$ and $\beta = 1-\alpha$.
#
# The residual error in this case is
#
# $$\begin{align}
# R &= p'' - y''\\
# &= 2\alpha - 6x \\
# \end{align}$$
#
# To find the best value of $\alpha$, we need to calculate
#
# $$I = \int_0^1 R^2 \, dx$$
#
# over our discrete mesh (set of intervals), and find the value of $\alpha$ that minimizes the total error $I$.
#
# The main advantage of the **finite element** method over the **finite difference** method is that the finite element method is less strict point-to-point convergence, and more sensitive to overall agreement.
# This is very similar to the relationship between the least-squares method and the Lagrange interpolating polynomial.
#
# A common way to implement the finite element method is to place a little trial function with limited local support on each interval.  (A triangular basis function centered at $x_i$ is a convenient option.)
# This choice of individual local trial functions guarantees a piecewise linear approximation of the overall trial function.
